# %% [markdown]
# To run this, press "*Runtime*" and press "*Run all*" on a **free** Tesla T4 Google Colab instance!
# <div class="align-center">
# <a href="https://unsloth.ai/"><img src="https://github.com/unslothai/unsloth/raw/main/images/unsloth%20new%20logo.png" width="115"></a>
# <a href="https://discord.gg/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/Discord button.png" width="145"></a>
# <a href="https://docs.unsloth.ai/"><img src="https://github.com/unslothai/unsloth/blob/main/images/documentation%20green%20button.png?raw=true" width="125"></a></a> Join Discord if you need help + ⭐ <i>Star us on <a href="https://github.com/unslothai/unsloth">Github</a> </i> ⭐
# </div>
#
# To install Unsloth on your own computer, follow the installation instructions on our Github page [here](https://docs.unsloth.ai/get-started/installing-+-updating).
#
# You will learn how to do [data prep](#Data), how to [train](#Train), how to [run the model](#Inference), & [how to save it](#Save)

# %% [markdown]
# ### News

# %% [markdown]
# Read our **[Qwen3 Guide](https://docs.unsloth.ai/basics/qwen3-how-to-run-and-fine-tune)** and check out our new **[Dynamic 2.0](https://docs.unsloth.ai/basics/unsloth-dynamic-2.0-ggufs)** quants which outperforms other quantization methods!
#
# Visit our docs for all our [model uploads](https://docs.unsloth.ai/get-started/all-our-models) and [notebooks](https://docs.unsloth.ai/get-started/unsloth-notebooks).

# %% [markdown]
# ### Installation

# %%
# !unzip data.zip
# Out:
# Archive:  data.zip
#    creating: data/
#    creating: data/豆沙饼@shanda_20230104/
#    creating: data/炒千张@HBSY_20210706_001/
#    creating: data/麻辣香锅@SHANDA_20211201/
#    creating: data/芹菜豆干3@njzw_20210829/
#    creating: data/黑椒猪扒2@HGD_20220901/
#    creating: data/西蓝花炒蒜茸@HGD_20211221/
#    creating: data/香辣猪手@HBSY_20210706_001/
#    creating: data/奥尔良烤鸡腿@SHANDA_20211201/
#    creating: data/冬菇煮肉片@GUANGWAI_20220614/
#    creating: data/237@JKDISH_20211230/
#    creating: data/豆芽肉丝@njzw_20210829/
#    creating: data/油麦菜@GUANGWAI_20220614/
#    creating: data/西瓜@njzw_20210829/
#    creating: data/猪耳朵@20190717_GXSJT_ZCGJJG/
#    creating: data/干锅生肠@ZHONGGUANGHE_20220901/
#    creating: data/肉饼@shanda_20230104/
#    creating: data/酸辣土豆丝@GUANGWAI_20220614/
#    creating: data/豆芽黄青红椒@TEST/
#    creating: data/小白菜炖杂丸@shanda_20230104/
#    creating: data/老鸭粉@HBSY_20210706_001/
#    creating: data/136@JKDISH_20211230/
#    creating: data/炒茄子@ZHONGGUANGHE_20220901/
#    creating: data/糖醋里脊@20190717_GXSJT_LYDX/
#    creating: data/1_11_31_白_馒头_32_燕麦___0/
#    creating: data/4_42_33__豆腐_31_木耳_11__0/
#    creating: data/青椒炒百合@HGD_20211221/
#    creating: data/5_51_21__豆干_21____2/
#    creating: data/1_11_32__面条_22____0/
#    creating: data/1_11_31_白_素饼_41____0/
#    creating: data/4_41_22__豆皮_11_木耳_11_白菜_11/
#    creating: data/五花肉白菜冻豆腐1@HGD_20211221/
#    creating: data/鸭肉饼@HGD_20211221/
#    creating: data/榨菜肉丝@HBSY_20210706_001/
#    creating: data/112@JKDISH_20211230/
#    creating: data/鱼丝@HGD_20211221/
#    creating: data/189@JKDISH_20211230/
#    creating: data/5@JKDISH_20211230/
#    creating: data/酸萝卜烧咸鸭@njzw_20210829/
#    creating: data/牛蛙@njzw_20210829/
#    creating: data/蒸山药@20190717-XML-20190620-BDNY/
#    creating: data/花生鸡爪@GUANGWAI_20220614/
#    creating: data/藕条@20190717_GXSJT_HBDX-2/
#    creating: data/杏鲍菇@20190717_GXSJT_LYDX-2/
#    creating: data/蜜汁南瓜@HGD_20211221/
#    creating: data/西米露@GUANGWAI_20220614/
#    creating: data/酱油粉丝肉片@ZHONGGUANGHE_20220901/
#    creating: data/蒜台牛肚@njzw_20210829/
#    creating: data/大米粥@20190717-XML-20190620-BDNY/
#    creating: data/烧鸭@ZHONGGUANGHE_20220901/
#    creating: data/炒虾仁@HBSY_20210706_001/
#    creating: data/包菜回锅肉@HBSY_20210706_001/
#    creating: data/冲菜肉片2@GUANGWAI_20220614/
#    creating: data/笋瓜炒鸡蛋@njzw_20210829/
#    creating: data/52@JKDISH_20211230/
#    creating: data/2_23_41__肉_11_洋葱_11__0/
#    creating: data/香菇肉丝@njzw_20210829/
#    creating: data/青菜粉丝@njzw_20210829/
#    creating: data/千页豆腐@20190717_GXSJT_LYDX-2/
#    creating: data/土豆片蟹味菇2@HGD_20211221/
#    creating: data/韭菜豆干肉丝@njzw_20210829/
#    creating: data/尖椒干豆腐@HGD_20211221/
#    creating: data/肉末雪菜炒年糕@HGD_20211221/
#    creating: data/红枣红糖发糕@njzw_20210829/
#    creating: data/6_61___香梨_____0/
#    creating: data/豆芽青椒@20190717_GXSJT_SDMTJS/
#    creating: data/爆浆鸡肉卷@SHANDA_20211201/
#    creating: data/菜花@20190717_GXSJT_LYDX-2/
#    creating: data/4_41_42__杏鲍菇_24_辣椒_35__0-1/
#    creating: data/麻辣香锅@HGD_20220901/
#    creating: data/27@JKDISH_20211230/
#    creating: data/2_23_42__肉_31_慈菇_31__0-1/
#    creating: data/八宝菜@HGD_20211221/
#    creating: data/香辣牛肉@ZHONGGUANGHE_20220901/
#    creating: data/肉片@20190717_GXSJT_HBDX-5/
#    creating: data/糖醋肉段@shanda_20230104/
#    creating: data/蚝油面筋@njzw_20210829/
#    creating: data/茄子炸土豆@ZHONGGUANGHE_20220901/
#    creating: data/凉拌木耳瓜条@HGD_20211221/
#    creating: data/剁椒鸭血@LITESHOP/
#    creating: data/清炒大白菜帮@HBSY_20210706_001/
#    creating: data/香辣蟹@ZHONGGUANGHE_20220901/
#    creating: data/青椒炒牛肉@ZHONGGUANGHE_20220901/
#    creating: data/水煮鸡柳@njzw_20210829/
#    creating: data/2_24_53__咸鸭蛋_81____0/
#    creating: data/水饺@HBSY_20210706_001/
#    creating: data/山楂小炒鸡@shanda_20230104/
#    creating: data/西兰花炒肉@njzw_20210829/
#    creating: data/回锅肉花菜@HBSY_20210706_001/
#    creating: data/山药煲鸡@GUANGWAI_20220614/
#    creating: data/椒盐饼@ZHONGGUANGHE_20220901/
#    creating: data/青椒鸡蛋红椒@HGD_20211221/
#    creating: data/雪梨糖水@GUANGWAI_20220614/
#    creating: data/黄瓜丝@HGD_20211221/
#    creating: data/绿豆@20190717_GXSJT_HBDX/
#    creating: data/香菇菜心@HBSY_20210706_001/
#    creating: data/红豆粥@njzw_20210829/
#    creating: data/蒜台回锅肉@LITESHOP/
#    creating: data/咸菜@HBSY_20210706_001/
#    creating: data/2_23_12__锅包肉_11____0/
#    creating: data/干炸鱿鱼@ZHONGGUANGHE_20220901/
#    creating: data/蓝莓山药@HGD_20220901/
#    creating: data/榨菜辣椒炒鸡蛋@ZHONGGUANGHE_20220901/
#    creating: data/水煮鱼片豆腐@njzw_20210829/
#    creating: data/辣炒墨鱼2@ZHONGGUANGHE_20220901/
#    creating: data/5_51_21__豆干_21____3/
#    creating: data/山药排骨@SHANDA_20211201/
#    creating: data/糖醋里脊@HBSY_20210706_001/
#    creating: data/肉片烧茄子@HGD_20211221/
#    creating: data/2_21_31__鱼_25____0-清蒸鱼尾/
#    creating: data/千页豆腐@20190717_GXSJT_HBDX/
#    creating: data/木耳拌黄瓜@20190717_GXSJT_ZCGJJG/
#    creating: data/木耳韭菜炒肉@ZHONGGUANGHE_20220901/
#    creating: data/245@JKDISH_20211230/
#    creating: data/冬瓜清蒸@20190717_GXSJT_LYDX/
#    creating: data/3_34_41__丸子_82_白菜_21__0/
#    creating: data/玉米排骨@SHANDA_20211201/
#    creating: data/茄汁鸡柳@HGD_20211221/
#    creating: data/日式抹茶蛋糕@HGD_20220901/
#    creating: data/1_11_31__发糕_61____0/
#    creating: data/炝花生@ZHONGGUANGHE_20220901/
#    creating: data/姜葱鸡@GUANGWAI_20220614/
#    creating: data/莲藕猪手汤@GUANGWAI_20220614/
#    creating: data/4_42_21__豆干_11_黄瓜_11__0/
#    creating: data/青豆@20190717_GXSJT_HBDX-3/
#    creating: data/144@JKDISH_20211230/
#    creating: data/巧克力面包圈@20190717-XML-20190620-BDNY/
#    creating: data/67@JKDISH_20211230/
#    creating: data/160@JKDISH_20211230/
#    creating: data/回锅肉@HGD_20211221/
#    creating: data/杏鲍菇炒肉@njzw_20210829/
#    creating: data/包子肉茴香2@SHANDA_20211201/
#    creating: data/排骨玉米汤@GUANGWAI_20220614/
#    creating: data/芹菜炒香肠@ZHONGGUANGHE_20220901/
#    creating: data/龙利鱼@ZHONGGUANGHE_20220901/
#    creating: data/小炒黄牛肉@HGD_20220901/
#    creating: data/龙利鱼@njzw_20210829/
#    creating: data/4_41_41__香菇_31_洋葱_21__0/
#    creating: data/梅菜烧肉@ZHONGGUANGHE_20220901/
#    creating: data/炒猪肝@LITESHOP/
#    creating: data/蒜黄鸡蛋@shanda_20230104/
#    creating: data/土豆片黄瓜条@HGD_20211221/
#    creating: data/5_51_21__豆干_12____0/
#    creating: data/孜然鸡柳@shanda_20230104/
#    creating: data/血豆腐白豆腐@20190717-XML-20190620-BDNY/
#    creating: data/1_11_11_红_包子_41____0/
#    creating: data/土豆胡萝卜咖喱炖肉@SHANDA_20211201/
#    creating: data/窝头@HGD_20211221/
#    creating: data/丝瓜@ZHONGGUANGHE_20220901/
#    creating: data/蒜台腊肉@ZHONGGUANGHE_20220901/
#    creating: data/3_34_21__肉_24_金针菇_24_青椒_24/
#    creating: data/214@JKDISH_20211230/
#    creating: data/杭椒炒开花肠@HGD_20211221/
#    creating: data/青红椒豆皮肉丝@njzw_20210829/
#    creating: data/豆腐皮@20190717_GXSJT_HBDX-3/
#    creating: data/香菇牛肉@GUANGWAI_20220614/
#    creating: data/火龙果@njzw_20210829/
#    creating: data/酱肘子@HGD_20211221/
#    creating: data/小白菜木耳@20190717_GXSJT_SXDX/
#    creating: data/2@JKDISH_20211230/
#    creating: data/燃烧乳烙@HGD_20220901/
#    creating: data/89@JKDISH_20211230/
#    creating: data/碎肉鸭1@ZHONGGUANGHE_20220901/
#    creating: data/毛刀鱼@njzw_20210829/
#    creating: data/西蓝花炒火腿@20190717_GXSJT_SXDX/
#    creating: data/253@JKDISH_20211230/
#    creating: data/炒火腿青椒4@HBSY_20210706_001/
#    creating: data/肉沫豆腐皮@shanda_20230104/
#    creating: data/青菜豆腐@HBSY_20210706_001/
#    creating: data/36@JKDISH_20211230/
#    creating: data/土豆排骨@SHANDA_20211201/
#    creating: data/炸盐酥鸡@HGD_20211221/
#    creating: data/牛肉酥皮饼2@SHANDA_20211201/
#    creating: data/鱿鱼炒洋葱@HGD_20211221/
#    creating: data/豆包@HGD_20211221/
#    creating: data/南瓜发糕@20190717-XML-20190620-BDNY/
#    creating: data/莴笋肉片@shanda_20230104/
#    creating: data/3_34_32__肥牛_11_藕_11__0/
#    creating: data/红糖包@ZHONGGUANGHE_20220901/
#    creating: data/煎饺子@20190717_GXSJT_ZCGJJG/
#    creating: data/海鲜菇肉丝@njzw_20210829/
#    creating: data/玉米饼@ZHONGGUANGHE_20220901/
#    creating: data/清炒笋丝@ZHONGGUANGHE_20220901/
#    creating: data/鸭杂盖炒米饭@shanda_20230104/
#    creating: data/清汤狮子头@HGD_20220901/
#    creating: data/南瓜窝窝头@HGD_20211221/
#    creating: data/花生米@20190717_GXSJT_SXDX/
#    creating: data/脆炸河虾@SHANDA_20211201/
#    creating: data/油菜豆腐@20190717_GXSJT_LYDX/
#    creating: data/鸡蛋柿子汤@HGD_20220901/
#    creating: data/上海青炒豆腐@HBSY_20210706_001/
#    creating: data/捞汁什锦@HGD_20220901/
#    creating: data/冬瓜肉片@ZHONGGUANGHE_20220901/
#    creating: data/203@JKDISH_20211230/
#    creating: data/鸡蛋卷@SHANDA_20211201/
#    creating: data/豆腐片@20190717-XML-20190620-BDNY/
#    creating: data/1_11___卷饼_21____0/
#    creating: data/细海带肉丝@njzw_20210829/
#    creating: data/炒五花肉虎皮青椒@GUANGWAI_20220614/
#    creating: data/腐竹五花肉@ZHONGGUANGHE_20220901/
#    creating: data/秋葵@ZHONGGUANGHE_20220901/
#    creating: data/海带丝@LITESHOP/
#    creating: data/红烧鲫鱼@njzw_20210829/
#    creating: data/香辣鱼头@ZHONGGUANGHE_20220901/
#    creating: data/切鸭@ZHONGGUANGHE_20220901/
#    creating: data/辣白菜@HBSY_20210706_001/
#    creating: data/虫草炖鸡@GUANGWAI_20220614/
#    creating: data/38@JKDISH_20211230/
#    creating: data/泡椒鸭杂浇头饭@SHANDA_20211201/
#    creating: data/木耳鸡蛋炒饭@HGD_20211221/
#    creating: data/21@JKDISH_20211230/
#    creating: data/炒青椒@GUANGWAI_20220614/
#    creating: data/烧鸡@ZHONGGUANGHE_20220901/
#    creating: data/西蓝花木耳@HGD_20211221/
#    creating: data/180@JKDISH_20211230/
#    creating: data/糖醋瓜条@HGD_20211221/
#    creating: data/西兰花@GUANGWAI_20220614/
#    creating: data/豆苗豆腐丝@20190717_GXSJT_LYDX/
#    creating: data/包子@20190717-XML-20190620-BDNY/
#    creating: data/煎蛋@GUANGWAI_20220614/
#    creating: data/荷兰豆炒山药@GUANGWAI_20220614/
#    creating: data/小炒鸡胗@ZHONGGUANGHE_20220901/
#    creating: data/奥尔良鸡块@njzw_20210829/
#    creating: data/墨鱼丸@GUANGWAI_20220614/
#    creating: data/菠菜木耳胡萝卜丝@20190717_GXSJT_SXDX-6/
#    creating: data/藕片木耳@HGD_20211221/
#    creating: data/海底椰鸡汤@ZHONGGUANGHE_20220901/
#    creating: data/大葱炒鸡蛋@ZHONGGUANGHE_20220901/
#    creating: data/227@JKDISH_20211230/
#    creating: data/鱼香肉丝@HBSY_20210706_001/
#    creating: data/芥兰@20190717_GXSJT_HBDX/
#    creating: data/4_42_53_黑_萝卜_34____0/
#    creating: data/鲈鱼@njzw_20210829/
#    creating: data/清蒸黄花鱼@ZHONGGUANGHE_20220901/
#    creating: data/木须肉@20190717_GXSJT_HBKJDX/
#    creating: data/鸡蛋炒河粉@HGD_20211221/
#    creating: data/蜜汁烧翅根@SHANDA_20211201/
#    creating: data/1_11_31__饺子_____3/
#    creating: data/13@JKDISH_20211230/
#    creating: data/88@JKDISH_20211230/
#    creating: data/韭菜鸡蛋@njzw_20210829/
#    creating: data/腐竹烧牛肉@GUANGWAI_20220614/
#    creating: data/114@JKDISH_20211230/
#    creating: data/黄瓜肘花@20190717-XML-20190620-BDNY/
#    creating: data/酱猪蹄@HGD_20211221/
#    creating: data/孜然牙签肉@HBSY_20210706_001/
#    creating: data/鸭蛋@ZHONGGUANGHE_20220901/
#    creating: data/青豆虾仁@HBSY_20210706_001/
#    creating: data/香辣口水鸡@HGD_20211221/
#    creating: data/丸子汤@HGD_20211221/
#    creating: data/蒜仔红烧肉@shanda_20230104/
#    creating: data/5_51_52__香干_32____0/
#    creating: data/日本豆腐金针菇@ZHONGGUANGHE_20220901/
#    creating: data/153@JKDISH_20211230/
#    creating: data/3_31_21__鹌鹑蛋__香肠_34__0/
#    creating: data/酸菜鱼片@HGD_20211221/
#    creating: data/蒸蛋@ZHONGGUANGHE_20220901/
#    creating: data/烩松肉@shanda_20230104/
#    creating: data/丸子豆腐汤@HGD_20211221/
#    creating: data/辣子鸡@GUANGWAI_20220614/
#    creating: data/烧鸡@GUANGWAI_20220614/
#    creating: data/酱菜@ZHONGGUANGHE_20220901/
#    creating: data/3_34_33__大骨棒_31_萝卜_31__0/
#    creating: data/青蒜猪肝@njzw_20210829/
#    creating: data/凉拌贡菜@ZHONGGUANGHE_20220901/
#    creating: data/4_41_12__蘑菇_31____0/
#    creating: data/177@JKDISH_20211230/
#    creating: data/豆腐丝韭菜@20190717_GXSJT_ZCGJJG-2/
#    creating: data/红烧鱼块2@njzw_20210829/
#    creating: data/麦粒发糕@shanda_20230104/
#    creating: data/干贝炒鸡蛋@ZHONGGUANGHE_20220901/
#    creating: data/馄饨@HGD_20211221/
#    creating: data/粉条@20190717_GXSJT_LYDX/
#    creating: data/馒头@20190717_GXSJT_ZCGJJG-2/
#    creating: data/4_41_53_白_萝卜_21____0/
#    creating: data/火腿手抓饼@SHANDA_20211201/
#    creating: data/干炸小鱼@ZHONGGUANGHE_20220901/
#    creating: data/辣炒鸡胗@GUANGWAI_20220614/
#    creating: data/西芹墨鱼@ZHONGGUANGHE_20220901/
#    creating: data/豆干@ZHONGGUANGHE_20220901/
#    creating: data/辣子鸡@HGD_20211221/
#    creating: data/稀饭@ZHONGGUANGHE_20220901/
#    creating: data/鸡蛋羹2@LITESHOP/
#    creating: data/猪蹄腐竹汤@GUANGWAI_20220614/
#    creating: data/拌海带结@njzw_20210829/
#    creating: data/爆炒猪腰@HGD_20211221/
#    creating: data/千页豆腐@20190717_GXSJT_HBDX-2/
#    creating: data/手抓鸡蛋饼@shanda_20230104/
#    creating: data/豆腐@20190717_GXSJT_HBKJDX/
#    creating: data/牛肉白菜海带@HGD_20211221/
#    creating: data/黄瓜花生@20190717_GXSJT_LYDX/
#    creating: data/包菜粉丝1@njzw_20210829/
#    creating: data/凤眼丸子双花拼盘@HGD_20211221/
#    creating: data/梅干菜饼@njzw_20210829/
#    creating: data/豆干青椒@20190717_GXSJT_LYDX/
#    creating: data/水煮全腰豆皮@njzw_20210829/
#    creating: data/芒果慕斯@HGD_20220901/
#    creating: data/蒜苔肉丝@njzw_20210829/
#    creating: data/2_23_42__肉_31____0/
#    creating: data/酱爆鸡丁@LITESHOP/
#    creating: data/杏鲍菇片@20190717_GXSJT_AHXHXY/
#    creating: data/空心菜@njzw_20210829/
#    creating: data/4_41_42__茄子_21____0/
#    creating: data/炒牛肚@HBSY_20210706_001/
#    creating: data/油豆腐@ZHONGGUANGHE_20220901/
#    creating: data/木耳腐竹香菜1@HGD_20211221/
#    creating: data/青椒炒肉丝@njzw_20210829/
#    creating: data/剁椒鸡块@njzw_20210829/
#    creating: data/212@JKDISH_20211230/
#    creating: data/麻团@njzw_20210829/
#    creating: data/蒜蓉粉丝扇贝@shanda_20230104/
#    creating: data/肉酱@ZHONGGUANGHE_20220901/
#    creating: data/茄子烧土豆@ZHONGGUANGHE_20220901/
#    creating: data/口水鸡@ZHONGGUANGHE_20220901/
#    creating: data/蘑菇炒鸡块@20190717_GXSJT_LYDX-4/
#    creating: data/4_41_42__茄子_31_土豆_31__0/
#    creating: data/蘑菇@20190717_GXSJT_SXDX/
#    creating: data/蛋花汤@20190717-XML-20190620-BDNY/
#    creating: data/包子@20190717_GXSJT_LYDX-4/
#    creating: data/255@JKDISH_20211230/
#    creating: data/2_21_42__鱼_21____0_红烧罗非鱼/
#    creating: data/包子肉@njzw_20210829/
#    creating: data/脆炸鸡块@ZHONGGUANGHE_20220901/
#    creating: data/皮腊猪肝@njzw_20210829/
#    creating: data/莴笋丝炒腐竹@GUANGWAI_20220614/
#    creating: data/西芹滑子蘑山药@HGD_20211221/
#    creating: data/洋葱肉片@njzw_20210829/
#    creating: data/银耳黄桃@HGD_20211221/
#    creating: data/4_41_21__毛豆_45_茭白_24__0/
#    creating: data/炒面@ZHONGGUANGHE_20220901/
#    creating: data/包菜炒千张@HBSY_20210706_001/
#    creating: data/1_11_31__胡萝卜_31_红薯_31__0/
#    creating: data/菠菜花生@HGD_20211221/
#    creating: data/萝卜药膳炖龙骨@ZHONGGUANGHE_20220901/
#    creating: data/芥菜大骨汤@ZHONGGUANGHE_20220901/
#    creating: data/黄瓜拌菜5@HGD_20211221/
#    creating: data/青菜粥@njzw_20210829/
#    creating: data/3_33_35__乌鸡_31_山药_31__0/
#    creating: data/韭菜炒鸡蛋2@ZHONGGUANGHE_20220901/
#    creating: data/虾饺包菜@20190717_GXSJT_LYDX/
#    creating: data/炒火腿2@HBSY_20210706_001/
#    creating: data/豆腐@20190717_GXSJT_ZCGJJG/
#    creating: data/炸全翅@ZHONGGUANGHE_20220901/
#    creating: data/炒饭@ZHONGGUANGHE_20220901/
#    creating: data/毛豆@ZHONGGUANGHE_20220901/
#    creating: data/鸭块@HBSY_20210706_001/
#    creating: data/春卷@ZHONGGUANGHE_20220901/
#    creating: data/老北京肉饼@HGD_20220901/
#    creating: data/三角枣发糕@shanda_20230104/
#    creating: data/红烧肉@LITESHOP/
#    creating: data/玉米粒@20190717_GXSJT_LYDX/
#    creating: data/京葱发面饼@20190717_GXSJT_LYDX/
#    creating: data/咕老肉@GUANGWAI_20220614/
#    creating: data/2_22_31_白_鸡翅_____0/
#    creating: data/138@JKDISH_20211230/
#    creating: data/蒸紫薯@LITESHOP/
#    creating: data/3_34_42__肉_31_萝卜_31__0-1/
#    creating: data/水芹2@SHANDA_20211201/
#    creating: data/年糕小炒鸡@njzw_20210829/
#    creating: data/葱段烧鸭血@shanda_2023_0104/
#    creating: data/红糖发糕@GUANGWAI_20220614/
#    creating: data/莴苣虾仁@SHANDA_20211201/
#    creating: data/鸡米花洋葱2@HGD_20211221/
#    creating: data/海带烧肉@njzw_20210829/
#    creating: data/2_21_33__鱼_31____0/
#    creating: data/丝瓜蘑菇@20190717-XML-20190620-BDNY/
#    creating: data/冬瓜肉丸@SHANDA_20211201/
#    creating: data/78@JKDISH_20211230/
#    creating: data/平菇肉丝@njzw_20210829/
#    creating: data/榨菜炒肉丝@ZHONGGUANGHE_20220901/
#    creating: data/煲仔饭肉酱@ZHONGGUANGHE_20220901/
#    creating: data/光明奶@ZHONGGUANGHR_20240225/
#    creating: data/土豆青椒肉片@ZHONGGUANGHE_20220901/
#    creating: data/119@JKDISH_20211230/
#    creating: data/青椒西红柿洋葱炒香肠@20190717_GXSJT_LYDX/
#    creating: data/124@JKDISH_20211230/
#    creating: data/豆腐泡烧肉@HBSY_20210706_001/
#    creating: data/23@JKDISH_20211230/
#    creating: data/3_34_21__肉_24_毛豆_45_香菇_11/
#    creating: data/包菜丝肉丝@HGD_20211221/
#    creating: data/红烧年糕大虾@njzw_20210829/
#    creating: data/红烧日本豆腐蘑菇@HGD_20211221/
#    creating: data/宫保鸡丁@20190717_GXSJT_HBKJDX/
#    creating: data/鸡爪花生汤@GUANGWAI_20220614/
#    creating: data/山芋@njzw_20210829/
#    creating: data/泡菜粉条火腿@HBSY_20210706_001/
#    creating: data/鱼香肉丝@ZHONGGUANGHE_20220901/
#    creating: data/玉米蒸饺@shanda_20230104/
#    creating: data/茶叶@ZHONGGUANGHE_20220901/
#    creating: data/山药@20190717-XML-20190620-BDNY/
#    creating: data/芋头@ZHONGGUANGHE_20220901/
#    creating: data/雪菜大排@njzw_20210829/
#    creating: data/圆饼4@20190717_GXSJT_HBKJDX/
#    creating: data/4_41_61__菠菜_24_面筋_31__0/
#    creating: data/147@JKDISH_20211230/
#    creating: data/辣炒鸡丁@SHANDA_20211201/
#    creating: data/紫菜蛋花汤@GUANGWAI_20220614/
#    creating: data/蒜苗炒红烧肉@GUANGWAI_20220614/
#    creating: data/椒盐田鸡@ZHONGGUANGHE_20220901/
#    creating: data/花卷2@SHANDA_20211201/
#    creating: data/牛肉肠@HGD_20211221/
#    creating: data/白切鸡@HBSY_20210706_001/
#    creating: data/黄瓜炒肉片香干@HBSY_20210706_001/
#    creating: data/腐竹焖红烧肉@GUANGWAI_20220614/
#    creating: data/凉皮@20190717_GXSJT_AHXHXY/
#    creating: data/凉拌木耳@GUANGWAI_20220614/
#    creating: data/100@JKDISH_20211230/
#    creating: data/雪菜粉皮肉丝@njzw_20210829/
#    creating: data/豆芽韭菜胡萝卜丝@20190717_GXSJT_AHXHXY/
#    creating: data/1_13_31__青团_44____0/
#    creating: data/3_32_33__鱼__豆腐_31_剁椒_35/
#    creating: data/菜花2@20190717_GXSJT_LYDX-4/
#    creating: data/笋丝拌金针菇@GUANGWAI_20220614/
#    creating: data/煲仔饭滑鸡@ZHONGGUANGHE_20220901/
#    creating: data/地瓜肉丝@ZHONGGUANGHE_20220901/
#    creating: data/肉圆红烧@njzw_20210829/
#    creating: data/糖醋丸子@HBSY_20210706_001/
#    creating: data/花卷@20190717_GXSJT_LYDX-12/
#    creating: data/葱油肉片@HGD_20220901/
#    creating: data/1_11_31_棕_馒头_32____1/
#    creating: data/桂花糕@HGD_20220901/
#    creating: data/132@JKDISH_20211230/
#    creating: data/35@JKDISH_20211230/
#    creating: data/5_51_21__豆干_21____0/
#    creating: data/肉皮冻花生米@HGD_20211221/
#    creating: data/黄瓜拌菜7@HGD_20211221/
#    creating: data/青蒜豆皮@njzw_20210829/
#    creating: data/酸菜肉丝@HBSY_20210706_001/
#    creating: data/香干丁炒鸡丁@GUANGWAI_20220614/
#    creating: data/黄瓜@njzw_20210829/
#    creating: data/炒豆皮@GUANGWAI_20220614/
#    creating: data/3_32_35__鱼_31_豆腐_31__0/
#    creating: data/油饼2@HGD_20211221/
#    creating: data/杏鲍菇胡萝卜肉片@ZHONGGUANGHE_20220901/
#    creating: data/山药小@ZHONGGUANGHE_20220901/
#    creating: data/朵椒田鸡@ZHONGGUANGHE_20220901/
#    creating: data/茄子炒尖椒2@ZHONGGUANGHE_20220901/
#    creating: data/青椒回锅肉@ZHONGGUANGHE_20220901/
#    creating: data/三鲜肉圆@njzw_20210829/
#    creating: data/肥肠烧茄子@HGD_20220901/
#    creating: data/藕炖排骨@HBSY_20210706_001/
#    creating: data/3_34_21__肉_24_茄子_24__0-1/
#    creating: data/凉拌沙蛤@ZHONGGUANGHE_20220901/
#    creating: data/冬瓜@20190717_GXSJT_SXDX-2/
#    creating: data/千叶豆腐炒火腿@HBSY_20210706_001/
#    creating: data/4_41_53_黄_萝卜_11____0/
#    creating: data/水煮全腰豆皮海带@njzw_20210829/
#    creating: data/白切墨鱼@ZHONGGUANGHE_20220901/
#    creating: data/火腿娃娃菜@HBSY_20210706_001/
#    creating: data/哈蜜瓜@njzw_20210829/
#    creating: data/5_51_61__干豆腐_24____0/
#    creating: data/51@JKDISH_20211230/
#    creating: data/鱼香肉丝木耳@20190717_GXSJT_HBKJDX/
#    creating: data/油菜香菇@20190717-XML-20190620-BDNY/
#    creating: data/秋葵粉丝@20190717-XML-20190620-BDNY/
#    creating: data/清炒菜花肉片@GUANGWAI_20220614/
#    creating: data/水煮鱼@SHANDA_20211201/
#    creating: data/包菜木耳回锅肉@HBSY_20210706_001/
#    creating: data/4_41_21__架豆角_34____0/
#    creating: data/豆浆@ZHONGGUANGHE_20220901/
#    creating: data/娃娃菜@SHANDA_20211201/
#    creating: data/4_41_61__蘑菇_21_菠菜_21__0/
#    creating: data/盐水鸡肝@HGD_20211221/
#    creating: data/鸡心@20190717_GXSJT_HBDX/
#    creating: data/4_41_22__蒜黄_25____0/
#    creating: data/包子@HBSY_20210706_001/
#    creating: data/6@JKDISH_20211230/
#    creating: data/16@JKDISH_20211230/
#    creating: data/豇豆烧鸡@njzw_20210829/
#    creating: data/粉条蒸肉@HBSY_20210706_001/
#    creating: data/燕麦粥@HGD_20211221/
#    creating: data/4_41_22__菠菜_25____0/
#    creating: data/茄子肉丁面@SHANDA_20211201/
#    creating: data/西葫芦炒火腿@HBSY_20210706_001/
#    creating: data/酸辣藕片@shanda_20230104/
#    creating: data/凉拌鸭掌@ZHONGGUANGHE_20220901/
#    creating: data/木耳鸡蛋@20190717_GXSJT_LYDX-2/
#    creating: data/炝炒圆白菜@HGD_20211221/
#    creating: data/193@JKDISH_20211230/
#    creating: data/木耳炒肉@20190717-XML-20190620-BDNY/
#    creating: data/空心粉@HBSY_20210706_001/
#    creating: data/3_34_21__肉_11_洋葱_21__0/
#    creating: data/木耳青椒肉片@20190717_GXSJT_AHXHXY/
#    creating: data/四季豆炖猪蹄@njzw_20210829/
#    creating: data/黑椒肉丁饭@SHANDA_20211201/
#    creating: data/金针菇炒蛋@njzw_20210829/
#    creating: data/藕带炒牛肉@GUANGWAI_20220614/
#    creating: data/4_41_21__木耳_11_蘑菇_11__0/
#    creating: data/酒酿汤圆@ZHONGGUANGHE_20220901/
#    creating: data/火腿毛毛虫@shanda_20230104/
#    creating: data/蒜苗鸭肠@njzw_20210829/
#    creating: data/172@JKDISH_20211230/
#    creating: data/烩松肉@SHANDA_20211201/
#    creating: data/209@JKDISH_20211230/
#    creating: data/疙瘩汤@HGD_20211221/
#    creating: data/土豆片@20190717-XML-20190620-BDNY/
#    creating: data/豆沙包@HGD_20211221/
#    creating: data/拌黄瓜丝@GUANGWAI_20220614/
#    creating: data/2_23_61__猪头肉_11____0/
#    creating: data/韭黄炒肉@ZHONGGUANGHE_20220901/
#    creating: data/3_32_31_扇贝__粉丝_24_蒜泥_35/
#    creating: data/剁椒肘子@HGD_20220901/
#    creating: data/圆饼@20190717_GXSJT_HBKJDX/
#    creating: data/豆腐皮黄瓜丝@20190717_GXSJT_LYDX-4/
#    creating: data/4_42_53__黄瓜_11____0/
#    creating: data/青椒炒肉@20190717_GXSJT_HBKJDX-2/
#    creating: data/炸里脊肉@20190717_GXSJT_LYDX/
#    creating: data/蒸鸡蛋@njzw_20210829/
#    creating: data/滑蛋凉瓜@HGD_20220901/
#    creating: data/白菜油果@njzw_20210829/
#    creating: data/辣炒粉肠@ZHONGGUANGHE_20220901/
#    creating: data/拌面@HBSY_20210706_001/
#    creating: data/包子圆1@20190717-XML-20190620-BDNY/
#    creating: data/140@JKDISH_20211230/
#    creating: data/大麦茶2@SHANDA_20211201/
#    creating: data/辣子鸡@shanda_20230104/
#    creating: data/香菜土豆丝@shanda_20230104/
#    creating: data/牛肉丸1@GUANGWAI_20220614/
#    creating: data/剁椒蒸草鱼@ZHONGGUANGHE_20220901/
#    creating: data/蘑菇炒腊肉@LITESHOP/
#    creating: data/4_41_12__土豆_12____0/
#    creating: data/莴笋丝@20190717_GXSJT_SXDX/
#    creating: data/孜然鸭胸@20190717-XML-20190620-BDNY/
#    creating: data/红枣发糕@HGD_20211221/
#    creating: data/青红椒炒腊肉@ZHONGGUANGHE_20220901/
#    creating: data/香菇菜花@GUANGWAI_20220614/
#    creating: data/4_42_53__地环_____0/
#    creating: data/63@JKDISH_20211230/
#    creating: data/盐水花生@njzw_20210829/
#    creating: data/韭菜苔肉丝@njzw_20210829/
#    creating: data/炒花饭@HBSY_20210706_001/
#    creating: data/豆腐皮豆芽@20190717_GXSJT_LYDX-3/
#    creating: data/羊肉锅粑@HBSY_20210706_001/
#    creating: data/三鲜烩皮肚木耳火腿@njzw_20210829/
#    creating: data/蟹味菇@HGD_20211221/
#    creating: data/杏鲍菇柿子椒@shanda_20230104/
#    creating: data/四喜烤麸@SHANDA_20211201/
#    creating: data/椒盐小虾@ZHONGGUANGHE_20220901/
#    creating: data/韭菜香干肉丝@njzw_20210829/
#    creating: data/腐竹肉片@GUANGWAI_20220614/
#    creating: data/山药烧香菇@HGD_20211221/
#    creating: data/青椒炒红肠@ZHONGGUANGHE_20220901/
#    creating: data/苜蓿扇贝@SHANDA_20211201/
#    creating: data/木耳西葫芦@20190717_GXSJT_AHXHXY/
#    creating: data/肘子叉烧@ZHONGGUANGHE_20220901/
#    creating: data/笋丝木耳红椒@HGD_20211221/
#    creating: data/3_32_61__鱼皮_24_彩椒_24__0/
#    creating: data/19@JKDISH_20211230/
#    creating: data/红烧鲅鱼@20190717_GXSJT_SXDX/
#    creating: data/白干烧肉@ZHONGGUANGHE_20220901/
#    creating: data/9@JKDISH_20211230/
#    creating: data/82@JKDISH_20211230/
#    creating: data/黄桃水果罐头@HGD_20220901/
#    creating: data/干炒鸡丁@njzw_20210829/
#    creating: data/马蹄@njzw_20210829/
#    creating: data/青椒炒猪肝@20190717_GXSJT_LYDX/
#    creating: data/芋头烧排骨@njzw_20210829/
#    creating: data/粉条白菜回锅肉@HBSY_20210706_001/
#    creating: data/肉丝尖椒炒藕丝1@HGD_20211221/
#    creating: data/1_13_44__面包_41_葡萄干___0/
#    creating: data/可乐@HGD_20211221/
#    creating: data/小米粥@GUANGWAI_20220614/
#    creating: data/豆沙饼@20190717-XML-20190620-BDNY/
#    creating: data/孜然饼@HGD_20211221/
#    creating: data/玉米面贴饼子@shanda_20230104/
#    creating: data/157@JKDISH_20211230/
#    creating: data/鸡蛋饼@SHANDA_20211201/
#    creating: data/4_41_45_红_地瓜_31____0/
#    creating: data/鱼卷丸@20190717_GXSJT_LYDX-2/
#    creating: data/青椒炒肉片@GUANGWAI_20220614/
#    creating: data/金针菇玉子豆腐@ZHONGGUANGHE_20220901/
#    creating: data/青蒜炒豆干@HGD_20220901/
#    creating: data/扇贝@ZHONGGUANGHE_20220901/
#    creating: data/打包哈密瓜@shanda_20230104/
#    creating: data/鲜虾豆腐@shanda_20230104/
#    creating: data/扁豆@ZHONGGUANGHE_20220901/
#    creating: data/苦瓜蒸肉@ZHONGGUANGHE_20220901/
#    creating: data/酸菜鱼1@njzw_20210829/
#    creating: data/山药炒笋@HGD_20211221/
#    creating: data/红烧带鱼笋片@20190717-XML-20190620-BDNY/
#    creating: data/粉蒸排骨@HGD_20211221/
#    creating: data/麻花酥@20190717-XML-20190620-BDNY/
#    creating: data/49@JKDISH_20211230/
#    creating: data/软炸小酥肉@HGD_20220901/
#    creating: data/小炒猪肝@HBSY_20210706_001/
#    creating: data/宽海带肉丝@njzw_20210829/
#    creating: data/萝卜油豆腐炖鸭@ZHONGGUANGHE_20220901/
#    creating: data/杏包菇肉丝@ZHONGGUANGHE_20220901/
#    creating: data/软炸虾仁@SHANDA_20211201/
#    creating: data/酸奶3@shanda_20230104/
#    creating: data/猪肉片@GUANGWAI_20220614/
#    creating: data/白切鸡@GUANGWAI_20220614/
#    creating: data/鱼香茄子2@HBSY_20210706_001/
#    creating: data/双鱼@HGD_20211221/
#    creating: data/荷兰豆炒辣肉@GUANGWAI_20220614/
#    creating: data/包子肉@SHANDA_20211201/
#    creating: data/豆芽@ZHONGGUANGHE_20220901/
#    creating: data/清蒸切鱼块@HGD_20211221/
#    creating: data/杂粮玉米铁杆山药@njzw_20210829/
#    creating: data/鸡丁炒黄瓜丁花生@ZHONGGUANGHE_20220901/
#    creating: data/192@JKDISH_20211230/
#    creating: data/4_42_35__鸡蛋_71_胡萝卜_34_木耳_24/
#    creating: data/炒肠粉@ZHONGGUANGHE_20220901/
#    creating: data/包菜炒肉方火腿@20190717_GXSJT_LYDX-2/
#    creating: data/134@JKDISH_20211230/
#    creating: data/白灼菜心@HGD_20220901/
#    creating: data/黄豆烧公鸡@ZHONGGUANGHE_20220901/
#    creating: data/西葫芦胡萝卜丝@ZHONGGUANGHE_20220901/
#    creating: data/青椒炒肉1@njzw_20210829/
#    creating: data/3_31_61__皮蛋_31_黄瓜_11__0/
#    creating: data/红烧鱼头@HGD_20211221/
#    creating: data/孜然鸭丁@njzw_20210829/
#    creating: data/芹菜豆干3@HGD_20211221/
#    creating: data/菠萝排骨@njzw_20210829/
#    creating: data/1_13_44__面包_41_燕麦_45__0/
#    creating: data/包菜粉条@ZHONGGUANGHE_20220901/
#    creating: data/什锦菜@njzw_20210829/
#    creating: data/玉米粒@HGD_20211221/
#    creating: data/肠粉@GUANGWAI_20220614/
#    creating: data/土豆回锅肉@HBSY_20210706_001/
#    creating: data/萝卜烧肉@20210801-NJZLP-OLD-SAMPLES/
#    creating: data/鸡腿大@ZHONGGUANGHE_20220901/
#    creating: data/2_21_42__酥鱼_25____0/
#    creating: data/杏鲍菇@20190717_GXSJT_LYDX/
#    creating: data/辣炒猪尾@ZHONGGUANGHE_20220901/
#    creating: data/花卷糖@HGD_20211221/
#    creating: data/金瓜板栗红烧肉@shanda_20230104/
#    creating: data/干锅菜花@njzw_20210829/
#    creating: data/5_51_35__豆腐脑_____0/
#    creating: data/白米汤@HBSY_20210706_001/
#    creating: data/豆泡@GUANGWAI_20220614/
#    creating: data/炒苦瓜@LITESHOP/
#    creating: data/乌鸡汤@HGD_20220901/
#    creating: data/炸牙签肉@HGD_20211221/
#    creating: data/清炒窝笋丝@njzw_20210829/
#    creating: data/25@JKDISH_20211230/
#    creating: data/122@JKDISH_20211230/
#    creating: data/菠菜@HBSY_20210706_001/
#    creating: data/丝瓜肉片@GUANGWAI_20220614/
#    creating: data/日本豆腐2@GUANGWAI_20220614/
#    creating: data/生蚝葱花炒鸡蛋@ZHONGGUANGHE_20220901/
#    creating: data/淮山猪蹄汤@GUANGWAI_20220614/
#    creating: data/三杯鸡@SHANDA_20211201/
#    creating: data/油菜烧土豆片1@HGD_20211221/
#    creating: data/甲鱼@njzw_20210829/
#    creating: data/芽菜炒肉@HGD_20211221/
#    creating: data/黄粘米饭@HGD_20211221/
#    creating: data/62@JKDISH_20211230/
#    creating: data/酱香饼@20190717_GXSJT_AHXHXY/
#    creating: data/黄瓜炒肉片花生2@TEST/
#    creating: data/孜然鱿鱼@LITESHOP/
#    creating: data/2_24_53__鸭蛋_____0/
#    creating: data/藕片炒肉@ZHONGGUANGHE_20220901/
#    creating: data/南瓜粥@njzw_20210829/
#    creating: data/酸菜粉@HGD_20211221/
#    creating: data/4_41_21__山药_11____0/
#    creating: data/卷心菜木耳@SHANDA_20211201/
#    creating: data/包菜粉丝@20190717_GXSJT_AHXHXY/
#    creating: data/4_41_35__土豆_34____0/
#    creating: data/粉丝肉沫@njzw_20210829/
#    creating: data/小炒鸡杂@ZHONGGUANGHE_20220901/
#    creating: data/84@JKDISH_20211230/
#    creating: data/118@JKDISH_20211230/
#    creating: data/183@JKDISH_20211230/
#    creating: data/荷叶粥@20190717_GXSJT_ZCGJJG/
#    creating: data/黑椒里脊@SHANDA_20211201/
#    creating: data/原汁肘块@HGD_20220901/
#    creating: data/22@JKDISH_20211230/
#    creating: data/红烧肉@20190717-XML-20190620-BDNY/
#    creating: data/木耳豆腐@HGD_20211221/
#    creating: data/2_21_42__鱼_25____0/
#    creating: data/小白菜丸子@shanda_20230104@shanda_20230104/
#    creating: data/1_11_31__面_51_豆沙___0/
#    creating: data/水果罐头@HGD_20211221/
#    creating: data/5_51_42__千叶豆腐_11_青椒_11__0/
#    creating: data/三角发糕@shanda_20230104/
#    creating: data/四圆子@HGD_20211221/
#    creating: data/干锅土豆片@LITESHOP/
#    creating: data/肉卷2@SHANDA_20211201/
#    creating: data/冬瓜筒骨玉米@HGD_20211221/
#    creating: data/剁椒鱼头@ZHONGGUANGHE_20220901/
#    creating: data/尖椒炒鸡蛋@ZHONGGUANGHE_20220901/
#    creating: data/黄豆蒸排骨@GUANGWAI_20220614/
#    creating: data/蒜香粉肠@ZHONGGUANGHE_20220901/
#    creating: data/菠菜肉片@shanda_20230104/
#    creating: data/梅菜@ZHONGGUANGHE_20220901/
#    creating: data/皮蛋瘦肉粥@ZHONGGUANGHE_20220901/
#    creating: data/酱三样@SHANDA_20211201/
#    creating: data/花卷3@SHANDA_20211201/
#    creating: data/豆腐片白菜@20190717_GXSJT_SXDX/
#    creating: data/133@JKDISH_20211230/
#    creating: data/腐竹蒜苗肉丝2@njzw_20210829/
#    creating: data/黄瓜@20190717_GXSJT_ZCGJJG/
#    creating: data/杂粮紫薯@njzw_20210829/
#    creating: data/92@JKDISH_20211230/
#    creating: data/萝卜牛肚@ZHONGGUANGHE_20220901/
#    creating: data/回锅肉蒜苔花菜@HBSY_20210706_001/
#    creating: data/黄瓜片小咸菜@njzw_20210829/
#    creating: data/黄瓜拌红烧肉@shanda_20230104/
#    creating: data/佛手瓜肉片@ZHONGGUANGHE_20220901/
#    creating: data/萝卜干炒蛋@ZHONGGUANGHE_20220901/
#    creating: data/1_13_44__面包_42____0/
#    creating: data/3_34_41__肉_24_架豆角_25__0/
#    creating: data/5_51_52__香干_21____0/
#    creating: data/圆饼2@20190717_GXSJT_HBKJDX/
#    creating: data/3_34_42__肉_31_萝卜_31__0-2/
#    creating: data/肉沫豆腐@SHANDA_20211201/
#    creating: data/上校鸡块@HGD_20211221/
#    creating: data/4_41_41__茄子_31_土豆_31_青椒_25/
#    creating: data/玉米粒@GUANGWAI_20220614/
#    creating: data/蒸饺@HBSY_20210706_001/
#    creating: data/窝笋丝鸡蛋@njzw_20210829/
#    creating: data/小米粥@20190717_GXSJT_ZCGJJG/
#    creating: data/红烧猪脚@GUANGWAI_20220614/
#    creating: data/黄花菜@njzw_20210829/
#    creating: data/蒜苗鸡杂@njzw_20210829/
#    creating: data/肉丝面@HGD_20211221/
#    creating: data/冬瓜鱼丸@shanda_20230104/
#    creating: data/香菇粉丝汤@HGD_20211221/
#    creating: data/花卷@20190717_GXSJT_LYDX-8/
#    creating: data/青枣@GUANGWAI_20220614/
#    creating: data/菠菜A@20190717_GXSJT_SXDX-3/
#    creating: data/猪肝@HGD_20211221/
#    creating: data/美味泡菜@HGD_20220901/
#    creating: data/1_13_12_金黄_饼_41_芝麻___0/
#    creating: data/杏鲍菇炒肉@GUANGWAI_20220614/
#    creating: data/芹菜粉@HGD_20211221/
#    creating: data/糖醋瓦块鱼土豆泥拼盘@HGD_20211221/
#    creating: data/紫甘蓝@20190717-XML-20190620-BDNY/
#    creating: data/菌菇滑蛋@SHANDA_20211201/
#    creating: data/煎海杂鱼@ZHONGGUANGHE_20220901/
#    creating: data/木耳小白菜@HGD_20211221/
#    creating: data/香芹豆腐丝@GUANGWAI_20220614/
#    creating: data/3_33_33__鹅_31_莴笋_31_胡萝卜_31__0/
#    creating: data/肥肠@njzw_20210829/
#    creating: data/海鲜菇炒塔菜2@HGD_20220901/
#    creating: data/4_41_21__杏鲍菇_11_木耳_11__0/
#    creating: data/腐乳橄榄菜@ZHONGGUANGHE_20220901/
#    creating: data/煎蛋@njzw_20210829/
#    creating: data/木耳山药青豆@njzw_20210829/
#    creating: data/孜然鱼豆腐@HGD_20211221/
#   inflating: data/豆沙饼@shanda_20230104/20211224121457_TC14D16T40024_0e417208647011ec82f530d042ea3a21__9&81&246&316.jpg
#   inflating: data/豆沙饼@shanda_20230104/20211224121457_TC14D16T40024_0e417208647011ec82f530d042ea3a21__9&81&246&316.txt
#   inflating: data/炒千张@HBSY_20210706_001/20210505120844_8190820014216_00044bdf17d1$336_158_684_524.jpg
#   inflating: data/炒千张@HBSY_20210706_001/20210505120844_8190820014216_00044bdf17d1$336_158_684_524.txt
#   inflating: data/麻辣香锅@SHANDA_20211201/20211029114526_TC14D16T40024_a75ad6be386a11ecb6e730d042ea3a21__989&45&1519&573.txt
#   inflating: data/麻辣香锅@SHANDA_20211201/20211029114526_TC14D16T40024_a75ad6be386a11ecb6e730d042ea3a21__989&45&1519&573.jpg
#   inflating: data/芹菜豆干3@njzw_20210829/北大菜品&芹菜香干_20190313164103_178_7&747&403&1236&879.jpg
#   inflating: data/芹菜豆干3@njzw_20210829/北大菜品&芹菜香干_20190313164103_178_7&747&403&1236&879.txt
#   inflating: data/黑椒猪扒2@HGD_20220901/202208161202018__420&188&1128&887.jpg
#   inflating: data/黑椒猪扒2@HGD_20220901/202208161202018__420&188&1128&887.txt
#   inflating: data/西蓝花炒蒜茸@HGD_20211221/20201130120119_8190820014235_00044bdf3fdd__275&354&737&783.txt
#   inflating: data/西蓝花炒蒜茸@HGD_20211221/20201130120119_8190820014235_00044bdf3fdd__275&354&737&783.jpg
#   inflating: data/香辣猪手@HBSY_20210706_001/20210510120730_8190820014261_00044bf6d83d$461_449_836_790.jpg
#   inflating: data/香辣猪手@HBSY_20210706_001/20210510120730_8190820014261_00044bf6d83d$461_449_836_790.txt
#   inflating: data/奥尔良烤鸡腿@SHANDA_20211201/20211104122302_TC14D16T40024_e64a25c63d2611ecb6e730d042ea3a21__285&189&508&642.txt
#   inflating: data/奥尔良烤鸡腿@SHANDA_20211201/20211104122302_TC14D16T40024_e64a25c63d2611ecb6e730d042ea3a21__285&189&508&642.jpg
#   inflating: data/冬菇煮肉片@GUANGWAI_20220614/20211228122220_KM16D0B540160_20211228122220_bf60306a6795__324&54&540&270.txt
#   inflating: data/冬菇煮肉片@GUANGWAI_20220614/20211228122220_KM16D0B540160_20211228122220_bf60306a6795__324&54&540&270.jpg
#   inflating: data/237@JKDISH_20211230/243237.txt
#   inflating: data/237@JKDISH_20211230/243237.jpg
#   inflating: data/豆芽肉丝@njzw_20210829/20210511113250_8190820014243_00044bded76f__604&229&955&590.jpg
#   inflating: data/豆芽肉丝@njzw_20210829/20210511113250_8190820014243_00044bded76f__604&229&955&590.txt
#   inflating: data/油麦菜@GUANGWAI_20220614/20220421121604_KM16D0B540147_20220421121604_c2ea4ba6c129__101&152&468&875.jpg
#   inflating: data/油麦菜@GUANGWAI_20220614/20220421121604_KM16D0B540147_20220421121604_c2ea4ba6c129__101&152&468&875.txt
#   inflating: data/西瓜@njzw_20210829/20210521113051_8190820012270_00044be03557__1017&588&1351&911.jpg
#   inflating: data/西瓜@njzw_20210829/20210521113051_8190820012270_00044be03557__1017&588&1351&911.txt
#   inflating: data/猪耳朵@20190717_GXSJT_ZCGJJG/诸城高级技工学校-托盘-中餐-20190116165425_20399$688_124_1213_503.txt
#   inflating: data/猪耳朵@20190717_GXSJT_ZCGJJG/诸城高级技工学校-托盘-中餐-20190116165425_20399$688_124_1213_503.jpg
#   inflating: data/干锅生肠@ZHONGGUANGHE_20220901/20220608172522-2.jpg
#   inflating: data/干锅生肠@ZHONGGUANGHE_20220901/20220608172522-2.txt
#   inflating: data/肉饼@shanda_20230104/20220310120302_TC14D16T40024_fb4213fea02611ecad0130d042ea3a21__451&196&704&473.txt
#   inflating: data/肉饼@shanda_20230104/20220310120302_TC14D16T40024_fb4213fea02611ecad0130d042ea3a21__451&196&704&473.jpg
#   inflating: data/酸辣土豆丝@GUANGWAI_20220614/20220301122736_KM16D0B540160_20220301122736_ebdd1c4e9917__555&668&1074&1156.jpg
#   inflating: data/酸辣土豆丝@GUANGWAI_20220614/20220301122736_KM16D0B540160_20220301122736_ebdd1c4e9917__555&668&1074&1156.txt
#   inflating: data/豆芽黄青红椒@TEST/20210507114156_8190820012270_00044be03557__350&633&712&1012.jpg
#   inflating: data/豆芽黄青红椒@TEST/20210507114156_8190820012270_00044be03557__350&633&712&1012.txt
#   inflating: data/小白菜炖杂丸@shanda_20230104/20220110115332_TC02211M40536_e10cb7c871c811ec82f530d042ea3a21__147&17&360&247.txt
#   inflating: data/小白菜炖杂丸@shanda_20230104/20220110115332_TC02211M40536_e10cb7c871c811ec82f530d042ea3a21__147&17&360&247.jpg
#   inflating: data/老鸭粉@HBSY_20210706_001/20210428182325_8190820014216_00044bdf17d1$714_131_1150_577.txt
#   inflating: data/老鸭粉@HBSY_20210706_001/20210428182325_8190820014216_00044bdf17d1$714_131_1150_577.jpg
#   inflating: data/136@JKDISH_20211230/23949.jpg
#   inflating: data/136@JKDISH_20211230/23949.txt
#   inflating: data/炒茄子@ZHONGGUANGHE_20220901/2022072018194520_655&322&1134&800_炒茄子_57.txt
#   inflating: data/炒茄子@ZHONGGUANGHE_20220901/2022072018194520_655&322&1134&800_炒茄子_57.jpg
#   inflating: data/糖醋里脊@20190717_GXSJT_LYDX/临沂大学-托盘-中餐-20190116165422_18146$541_545_986_998.txt
#   inflating: data/糖醋里脊@20190717_GXSJT_LYDX/临沂大学-托盘-中餐-20190116165422_18146$541_545_986_998.jpg
#   inflating: data/1_11_31_白_馒头_32_燕麦___0/北大菜品&燕麦馒头_20190425123646_19_7&805&547&1175&883.jpg
#   inflating: data/1_11_31_白_馒头_32_燕麦___0/北大菜品&燕麦馒头_20190425123646_19_7&805&547&1175&883.txt
#   inflating: data/4_42_33__豆腐_31_木耳_11__0/南京政务&00044bdebaf5_1573445829_45_7&838&300&1275&733.jpg
#   inflating: data/4_42_33__豆腐_31_木耳_11__0/南京政务&00044bdebaf5_1573445829_45_7&838&300&1275&733.txt
#   inflating: data/青椒炒百合@HGD_20211221/20210413120547_8190820012270_00044be03557$892_120_1238_461.jpg
#   inflating: data/青椒炒百合@HGD_20211221/20210413120547_8190820012270_00044be03557$892_120_1238_461.txt
#   inflating: data/5_51_21__豆干_21____2/高校-爱数&河南牧业经济学院-托盘-晚餐-20181225105834_761_11&1136&604&1474&945.txt
#   inflating: data/5_51_21__豆干_21____2/高校-爱数&河南牧业经济学院-托盘-晚餐-20181225105834_761_11&1136&604&1474&945.jpg
#   inflating: data/1_11_32__面条_22____0/高校-爱数&阳泉职业技术学院-托盘-中餐-20190110154532_249_9&960&367&1435&811.jpg
#   inflating: data/1_11_32__面条_22____0/高校-爱数&阳泉职业技术学院-托盘-中餐-20190110154532_249_9&960&367&1435&811.txt
#   inflating: data/1_11_31_白_素饼_41____0/高校-爱数&信阳农林学院-托盘-晚餐-20190110153139_11548_13&1210&580&1511&883.jpg
#   inflating: data/1_11_31_白_素饼_41____0/高校-爱数&信阳农林学院-托盘-晚餐-20190110153139_11548_13&1210&580&1511&883.txt
#   inflating: data/4_41_22__豆皮_11_木耳_11_白菜_11/南京政务&00044bdebaf5_1573529930_12_8&413&783&910&1239.jpg
#   inflating: data/4_41_22__豆皮_11_木耳_11_白菜_11/南京政务&00044bdebaf5_1573529930_12_8&413&783&910&1239.txt
#   inflating: data/五花肉白菜冻豆腐1@HGD_20211221/P90_20200103175426__265&308&865&970.jpg
#   inflating: data/五花肉白菜冻豆腐1@HGD_20211221/P90_20200103175426__265&308&865&970.txt
#   inflating: data/鸭肉饼@HGD_20211221/H_20200107075940__1055&418&1406&914.jpg
#   inflating: data/鸭肉饼@HGD_20211221/H_20200107075940__1055&418&1406&914.txt
#   inflating: data/榨菜肉丝@HBSY_20210706_001/20210326181238_8190820014216_00044bdf17d1$859_204_1231_557.jpg
#   inflating: data/榨菜肉丝@HBSY_20210706_001/20210326181238_8190820014216_00044bdf17d1$859_204_1231_557.txt
#   inflating: data/112@JKDISH_20211230/11602.jpg
#   inflating: data/112@JKDISH_20211230/11602.txt
#   inflating: data/鱼丝@HGD_20211221/20201216174257_8190820014236_00044bde74c0__1052&135&1279&379.jpg
#   inflating: data/鱼丝@HGD_20211221/20201216174257_8190820014236_00044bde74c0__1052&135&1279&379.txt
#   inflating: data/189@JKDISH_20211230/309980.jpg
#   inflating: data/189@JKDISH_20211230/309980.txt
#   inflating: data/5@JKDISH_20211230/479.jpg
#   inflating: data/5@JKDISH_20211230/479.txt
#   inflating: data/酸萝卜烧咸鸭@njzw_20210829/20210518114021_8190820012269_00044be01353__329&182&656&509.jpg
#   inflating: data/酸萝卜烧咸鸭@njzw_20210829/20210518114021_8190820012269_00044be01353__329&182&656&509.txt
#   inflating: data/牛蛙@njzw_20210829/20210514113555_8190820012282_00044bdebaf5__338&211&668&547.txt
#   inflating: data/牛蛙@njzw_20210829/20210514113555_8190820012282_00044bdebaf5__338&211&668&547.jpg
#   inflating: data/蒸山药@20190717-XML-20190620-BDNY/20190524125017$1129_701_1607_1208.txt
#   inflating: data/蒸山药@20190717-XML-20190620-BDNY/20190524125017$1129_701_1607_1208.jpg
#   inflating: data/花生鸡爪@GUANGWAI_20220614/20220412121326_KM16D0B540160_20220412121326_e6d6d288ba16__123&682&511&1136.txt
#   inflating: data/花生鸡爪@GUANGWAI_20220614/20220412121326_KM16D0B540160_20220412121326_e6d6d288ba16__123&682&511&1136.jpg
#   inflating: data/藕条@20190717_GXSJT_HBDX-2/湖北大学-托盘-中餐-20190116165448_36725$996_75_1541_539.txt
#   inflating: data/藕条@20190717_GXSJT_HBDX-2/湖北大学-托盘-中餐-20190116165448_36725$996_75_1541_539.jpg
#   inflating: data/杏鲍菇@20190717_GXSJT_LYDX-2/临沂大学-托盘-中餐-20190116165414_12530$1026_517_1529_984.jpg
#   inflating: data/杏鲍菇@20190717_GXSJT_LYDX-2/临沂大学-托盘-中餐-20190116165414_12530$1026_517_1529_984.txt
#   inflating: data/蜜汁南瓜@HGD_20211221/20201205123718_8190820014231_00044be07d1a__872&512&1263&929.txt
#   inflating: data/蜜汁南瓜@HGD_20211221/20201205123718_8190820014231_00044be07d1a__872&512&1263&929.jpg
#   inflating: data/西米露@GUANGWAI_20220614/20220309114609_KM16D0B540160_20220309114609_74eb90129f5b__0&599&415&1094.txt
#   inflating: data/西米露@GUANGWAI_20220614/20220309114609_KM16D0B540160_20220309114609_74eb90129f5b__0&599&415&1094.jpg
#   inflating: data/酱油粉丝肉片@ZHONGGUANGHE_20220901/2022071918103920_479&43&944&516_5元菜1_76.jpg
#   inflating: data/酱油粉丝肉片@ZHONGGUANGHE_20220901/2022071918103920_479&43&944&516_5元菜1_76.txt
#   inflating: data/蒜台牛肚@njzw_20210829/20210519113011_8190820012282_00044bdebaf5__318&133&700&479.txt
#   inflating: data/蒜台牛肚@njzw_20210829/20210519113011_8190820012282_00044bdebaf5__318&133&700&479.jpg
#   inflating: data/大米粥@20190717-XML-20190620-BDNY/20190531171602$1241_732_1648_1135.txt
#   inflating: data/大米粥@20190717-XML-20190620-BDNY/20190531171602$1241_732_1648_1135.jpg
#   inflating: data/烧鸭@ZHONGGUANGHE_20220901/2022072612161520_93&66&573&551_5元菜_62.txt
#   inflating: data/烧鸭@ZHONGGUANGHE_20220901/2022072612161520_93&66&573&551_5元菜_62.jpg
#   inflating: data/炒虾仁@HBSY_20210706_001/20210520123041_8190820014216_00044bdf17d1$942_515_1277_834.txt
#   inflating: data/炒虾仁@HBSY_20210706_001/20210520123041_8190820014216_00044bdf17d1$942_515_1277_834.jpg
#   inflating: data/包菜回锅肉@HBSY_20210706_001/20210330175702_8190820014218_00044bde74de$376_138_739_488.jpg
#   inflating: data/包菜回锅肉@HBSY_20210706_001/20210330175702_8190820014218_00044bde74de$376_138_739_488.txt
#   inflating: data/冲菜肉片2@GUANGWAI_20220614/20220412115142_KM16D0B540147_20220412115142_dda29790ba13__496&731&988&1200.txt
#   inflating: data/冲菜肉片2@GUANGWAI_20220614/20220412115142_KM16D0B540147_20220412115142_dda29790ba13__496&731&988&1200.jpg
#   inflating: data/笋瓜炒鸡蛋@njzw_20210829/20210521115500_8190820012282_00044bdebaf5__668&202&1032&607.txt
#   inflating: data/笋瓜炒鸡蛋@njzw_20210829/20210521115500_8190820012282_00044bdebaf5__668&202&1032&607.jpg
#   inflating: data/52@JKDISH_20211230/5279.jpg
#   inflating: data/52@JKDISH_20211230/5279.txt
#   inflating: data/2_23_41__肉_11_洋葱_11__0/美食广场&美食快充-托盘-中餐-20181121180650_775_8&1325&432&1830&1002.jpg
#   inflating: data/2_23_41__肉_11_洋葱_11__0/美食广场&美食快充-托盘-中餐-20181121180650_775_8&1325&432&1830&1002.txt
#   inflating: data/香菇肉丝@njzw_20210829/20210518180634_8190820012282_00044bdebaf5__322&200&663&559.jpg
#   inflating: data/香菇肉丝@njzw_20210829/20210518180634_8190820012282_00044bdebaf5__322&200&663&559.txt
#   inflating: data/青菜粉丝@njzw_20210829/20210519121022_8190820012270_00044be03557__941&564&1320&961.txt
#   inflating: data/青菜粉丝@njzw_20210829/20210519121022_8190820012270_00044be03557__941&564&1320&961.jpg
#   inflating: data/千页豆腐@20190717_GXSJT_LYDX-2/临沂大学-托盘-晚餐-20190116165400_1796$1117_55_1597_498.txt
#   inflating: data/千页豆腐@20190717_GXSJT_LYDX-2/临沂大学-托盘-晚餐-20190116165400_1796$1117_55_1597_498.jpg
#   inflating: data/土豆片蟹味菇2@HGD_20211221/20200110073958color11__695&403&1316&875.txt
#   inflating: data/土豆片蟹味菇2@HGD_20211221/20200110073958color11__695&403&1316&875.jpg
#   inflating: data/韭菜豆干肉丝@njzw_20210829/20210512180904_8190820012270_00044be03557__891&256&1243&634.jpg
#   inflating: data/韭菜豆干肉丝@njzw_20210829/20210512180904_8190820012270_00044be03557__891&256&1243&634.txt
#   inflating: data/尖椒干豆腐@HGD_20211221/H_20200107171047__1065&204&1656&797.txt
#   inflating: data/尖椒干豆腐@HGD_20211221/H_20200107171047__1065&204&1656&797.jpg
#   inflating: data/肉末雪菜炒年糕@HGD_20211221/20201202171905_8190820014235_00044bdf3fdd__847&135&1213&537.jpg
#   inflating: data/肉末雪菜炒年糕@HGD_20211221/20201202171905_8190820014235_00044bdf3fdd__847&135&1213&537.txt
#   inflating: data/红枣红糖发糕@njzw_20210829/20210525074053_8190820012270_00044be03557__396&574&759&878.txt
#   inflating: data/红枣红糖发糕@njzw_20210829/20210525074053_8190820012270_00044be03557__396&574&759&878.jpg
#   inflating: data/6_61___香梨_____0/南京政务&20191202111713_6&457&239&662&384.jpg
#   inflating: data/6_61___香梨_____0/南京政务&20191202111713_6&457&239&662&384.txt
#   inflating: data/豆芽青椒@20190717_GXSJT_SDMTJS/山东煤炭技师学院-托盘-中餐-20190116165402_3098$1014_135_1553_580.txt
#   inflating: data/豆芽青椒@20190717_GXSJT_SDMTJS/山东煤炭技师学院-托盘-中餐-20190116165402_3098$1014_135_1553_580.jpg
#   inflating: data/爆浆鸡肉卷@SHANDA_20211201/20211101112044_ff127b09f4eb458928b883113b1b22fc.jpg
#   inflating: data/爆浆鸡肉卷@SHANDA_20211201/20211101112044_ff127b09f4eb458928b883113b1b22fc.txt
#   inflating: data/菜花@20190717_GXSJT_LYDX-2/20211116112516_TC02211M40536_d1bc56f0468c11ecb6e730d042ea3a21__521&12&792&240.jpg
#   inflating: data/菜花@20190717_GXSJT_LYDX-2/20211116112516_TC02211M40536_d1bc56f0468c11ecb6e730d042ea3a21__521&12&792&240.txt
#   inflating: data/4_41_42__杏鲍菇_24_辣椒_35__0-1/美食广场&美食快充-托盘-中餐-20181121180651_1091_8&572&540&1142&1110.txt
#   inflating: data/4_41_42__杏鲍菇_24_辣椒_35__0-1/美食广场&美食快充-托盘-中餐-20181121180651_1091_8&572&540&1142&1110.jpg
#   inflating: data/麻辣香锅@HGD_20220901/2022082217120244_849&168&1535&1025_麻辣香锅_70.jpg
#   inflating: data/麻辣香锅@HGD_20220901/2022082217120244_849&168&1535&1025_麻辣香锅_70.txt
#   inflating: data/27@JKDISH_20211230/2681.txt
#   inflating: data/27@JKDISH_20211230/2681.jpg
#   inflating: data/2_23_42__肉_31_慈菇_31__0-1/南京政务&20191126115941_6&619&116&823&275.jpg
#   inflating: data/2_23_42__肉_31_慈菇_31__0-1/南京政务&20191126115941_6&619&116&823&275.txt
#   inflating: data/八宝菜@HGD_20211221/20201218120951_8190820014236_00044bde74c0__1040&197&1313&457.jpg
#   inflating: data/八宝菜@HGD_20211221/20201218120951_8190820014236_00044bde74c0__1040&197&1313&457.txt
#   inflating: data/香辣牛肉@ZHONGGUANGHE_20220901/2022062412095521_52&389&500&883_香辣牛肉_84.jpg
#   inflating: data/香辣牛肉@ZHONGGUANGHE_20220901/2022062412095521_52&389&500&883_香辣牛肉_84.txt
#   inflating: data/肉片@20190717_GXSJT_HBDX-5/湖北大学-托盘-中餐-20190116165451_38582$399_562_817_983.jpg
#   inflating: data/肉片@20190717_GXSJT_HBDX-5/湖北大学-托盘-中餐-20190116165451_38582$399_562_817_983.txt
#   inflating: data/糖醋肉段@shanda_20230104/20220526122925_TC02211M40536_6c765ab4dcac11ecb6b330d042ea3a21__86&216&332&433.txt
#   inflating: data/糖醋肉段@shanda_20230104/20220526122925_TC02211M40536_6c765ab4dcac11ecb6b330d042ea3a21__86&216&332&433.jpg
#   inflating: data/蚝油面筋@njzw_20210829/20200609112112_8190820014265_00044bdf1b76__351&272&734&601.txt
#   inflating: data/蚝油面筋@njzw_20210829/20200609112112_8190820014265_00044bdf1b76__351&272&734&601.jpg
#   inflating: data/茄子炸土豆@ZHONGGUANGHE_20220901/2022072617484320_109&749&586&1200_土豆茄子_67.jpg
#   inflating: data/茄子炸土豆@ZHONGGUANGHE_20220901/2022072617484320_109&749&586&1200_土豆茄子_67.txt
#   inflating: data/凉拌木耳瓜条@HGD_20211221/20200110082421color11__1000&134&1510&625.txt
#   inflating: data/凉拌木耳瓜条@HGD_20211221/20200110082421color11__1000&134&1510&625.jpg
#   inflating: data/剁椒鸭血@LITESHOP/20210830163029312478__407&455&770&846.jpg
#   inflating: data/剁椒鸭血@LITESHOP/20210830163029312478__407&455&770&846.txt
#   inflating: data/清炒大白菜帮@HBSY_20210706_001/20210413182108_8190820014218_00044bde74de$291_425_622_737.jpg
#   inflating: data/清炒大白菜帮@HBSY_20210706_001/20210413182108_8190820014218_00044bde74de$291_425_622_737.txt
#   inflating: data/香辣蟹@ZHONGGUANGHE_20220901/2022072117505120_3&226&461&985_香辣蟹_61.jpg
#   inflating: data/香辣蟹@ZHONGGUANGHE_20220901/2022072117505120_3&226&461&985_香辣蟹_61.txt
#   inflating: data/青椒炒牛肉@ZHONGGUANGHE_20220901/2022080212031620_464&136&953&632_青椒牛肉_68.txt
#   inflating: data/青椒炒牛肉@ZHONGGUANGHE_20220901/2022080212031620_464&136&953&632_青椒牛肉_68.jpg
#   inflating: data/水煮鸡柳@njzw_20210829/20210525180511_8190820012282_00044bdebaf5__1021&129&1334&482.txt
#   inflating: data/水煮鸡柳@njzw_20210829/20210525180511_8190820012282_00044bdebaf5__1021&129&1334&482.jpg
#   inflating: data/2_24_53__咸鸭蛋_81____0/北大菜品&咸鸭蛋_20190313160657_141_8&836&772&1026&1010.jpg
#   inflating: data/2_24_53__咸鸭蛋_81____0/北大菜品&咸鸭蛋_20190313160657_141_8&836&772&1026&1010.txt
#   inflating: data/水饺@HBSY_20210706_001/20210322182600_8190820014261_00044bf6d83d$610_479_1092_919.jpg
#   inflating: data/水饺@HBSY_20210706_001/20210322182600_8190820014261_00044bf6d83d$610_479_1092_919.txt
#   inflating: data/山楂小炒鸡@shanda_20230104/20211222120110_TC02211M40536_cc76c2fa62db11ec82f530d042ea3a21__279&5&495&220.txt
#   inflating: data/山楂小炒鸡@shanda_20230104/20211222120110_TC02211M40536_cc76c2fa62db11ec82f530d042ea3a21__279&5&495&220.jpg
#   inflating: data/西兰花炒肉@njzw_20210829/20210524113318_8190820014243_00044bded76f__336&553&649&892.txt
#   inflating: data/西兰花炒肉@njzw_20210829/20210524113318_8190820014243_00044bded76f__336&553&649&892.jpg
#   inflating: data/回锅肉花菜@HBSY_20210706_001/20210308121435_8190820014216_00044bdf17d1$431_107_788_428.jpg
#   inflating: data/回锅肉花菜@HBSY_20210706_001/20210308121435_8190820014216_00044bdf17d1$431_107_788_428.txt
#   inflating: data/山药煲鸡@GUANGWAI_20220614/20220329171835_KM16D0B540160_20220329171835_35b6e298af41__682&309&1071&733.txt
# ...
#   inflating: data/包菜粉丝@20190717_GXSJT_AHXHXY/安徽新华学院-托盘-中餐-20190116165502_46712$402_533_848_886.txt
#   inflating: data/4_41_35__土豆_34____0/高校-爱数&河南牧业经济学院-托盘-晚餐-20181225105835_1871_9&389&404&745&757.txt
#   inflating: data/4_41_35__土豆_34____0/高校-爱数&河南牧业经济学院-托盘-晚餐-20181225105835_1871_9&389&404&745&757.jpg
#   inflating: data/粉丝肉沫@njzw_20210829/20210527114328_8190820012267_00044bdfb899__680&279&1063&609.txt
#   inflating: data/粉丝肉沫@njzw_20210829/20210527114328_8190820012267_00044bdfb899__680&279&1063&609.jpg
#   inflating: data/小炒鸡杂@ZHONGGUANGHE_20220901/2022070618484320_699&607&1249&1151_5元菜_98.jpg
#   inflating: data/小炒鸡杂@ZHONGGUANGHE_20220901/2022070618484320_699&607&1249&1151_5元菜_98.txt
#   inflating: data/84@JKDISH_20211230/8842.txt
#   inflating: data/84@JKDISH_20211230/8842.jpg
#   inflating: data/118@JKDISH_20211230/12604.jpg
#   inflating: data/118@JKDISH_20211230/12604.txt
#   inflating: data/183@JKDISH_20211230/306924.txt
#   inflating: data/183@JKDISH_20211230/306924.jpg
#   inflating: data/荷叶粥@20190717_GXSJT_ZCGJJG/诸城高级技工学校-托盘-早餐-20190116165359_1128$446_168_818_536.jpg
#   inflating: data/荷叶粥@20190717_GXSJT_ZCGJJG/诸城高级技工学校-托盘-早餐-20190116165359_1128$446_168_818_536.txt
#   inflating: data/黑椒里脊@SHANDA_20211201/20211103113525_TC02211M40536_1533eee23c5711ecb6e730d042ea3a21__707&457&1212&922.txt
#   inflating: data/黑椒里脊@SHANDA_20211201/20211103113525_TC02211M40536_1533eee23c5711ecb6e730d042ea3a21__707&457&1212&922.jpg
#   inflating: data/原汁肘块@HGD_20220901/2022082411431844_645&2&1411&473_原汁肘块_75.txt
#   inflating: data/原汁肘块@HGD_20220901/2022082411431844_645&2&1411&473_原汁肘块_75.jpg
#   inflating: data/22@JKDISH_20211230/2116.jpg
#   inflating: data/22@JKDISH_20211230/2116.txt
#   inflating: data/红烧肉@20190717-XML-20190620-BDNY/20190606121902$741_416_1315_830.txt
#   inflating: data/红烧肉@20190717-XML-20190620-BDNY/20190606121902$741_416_1315_830.jpg
#   inflating: data/木耳豆腐@HGD_20211221/20210308115122_8190820012269_00044be01353$256_301_592_655.txt
#   inflating: data/木耳豆腐@HGD_20211221/20210308115122_8190820012269_00044be01353$256_301_592_655.jpg
#   inflating: data/2_21_42__鱼_25____0/北大菜品&20190520184142_10&1214&278&1692&828.txt
#   inflating: data/2_21_42__鱼_25____0/北大菜品&20190520184142_10&1214&278&1692&828.jpg
#   inflating: data/小白菜丸子@shanda_20230104@shanda_20230104/20220613114838_TC45P1CR40369_b55bd81ceacb11ecb6b330d042ea3a21__31&50&284&282.jpg
#   inflating: data/小白菜丸子@shanda_20230104@shanda_20230104/20220613114838_TC45P1CR40369_b55bd81ceacb11ecb6b330d042ea3a21__31&50&284&282.txt
#   inflating: data/1_11_31__面_51_豆沙___0/南京政务&00044bdebaf5_1574136882_57_9&939&884&1234&1217.jpg
#   inflating: data/1_11_31__面_51_豆沙___0/南京政务&00044bdebaf5_1574136882_57_9&939&884&1234&1217.txt
#   inflating: data/水果罐头@HGD_20211221/20200107072951color11__1293&935&1634&1280.txt
#   inflating: data/水果罐头@HGD_20211221/20200107072951color11__1293&935&1634&1280.jpg
#   inflating: data/5_51_42__千叶豆腐_11_青椒_11__0/高校-爱数&信阳农林学院-托盘-中餐-20190110153120_4192_13&678&136&973&414.jpg
#   inflating: data/5_51_42__千叶豆腐_11_青椒_11__0/高校-爱数&信阳农林学院-托盘-中餐-20190110153120_4192_13&678&136&973&414.txt
#   inflating: data/三角发糕@shanda_20230104/20220303113149_TC02211M40536_75c394349aa211ec842230d042ea3a21__69&277&358&486.txt
#   inflating: data/三角发糕@shanda_20230104/20220303113149_TC02211M40536_75c394349aa211ec842230d042ea3a21__69&277&358&486.jpg
#   inflating: data/四圆子@HGD_20211221/20210408120905_8190820012282_00044bdebaf5$370_135_685_427.jpg
#   inflating: data/四圆子@HGD_20211221/20210408120905_8190820012282_00044bdebaf5$370_135_685_427.txt
#   inflating: data/干锅土豆片@LITESHOP/20210830163029413991__935&77&1332&473.jpg
#   inflating: data/干锅土豆片@LITESHOP/20210830163029413991__935&77&1332&473.txt
#   inflating: data/肉卷2@SHANDA_20211201/20211123113506_TC14D16T40024_59c121944c0e11ec82f530d042ea3a21__55&467&338&600.txt
#   inflating: data/肉卷2@SHANDA_20211201/20211123113506_TC14D16T40024_59c121944c0e11ec82f530d042ea3a21__55&467&338&600.jpg
#   inflating: data/冬瓜筒骨玉米@HGD_20211221/20210510120810_8190820012274_00044bdf406f$350_394_793_807.jpg
#   inflating: data/冬瓜筒骨玉米@HGD_20211221/20210510120810_8190820012274_00044bdf406f$350_394_793_807.txt
#   inflating: data/剁椒鱼头@ZHONGGUANGHE_20220901/20220608175045-0.jpg
#   inflating: data/剁椒鱼头@ZHONGGUANGHE_20220901/20220608175045-0.txt
#   inflating: data/尖椒炒鸡蛋@ZHONGGUANGHE_20220901/2022071017295520__757&276&1298&832.jpg
#   inflating: data/尖椒炒鸡蛋@ZHONGGUANGHE_20220901/2022071017295520__757&276&1298&832.txt
#   inflating: data/黄豆蒸排骨@GUANGWAI_20220614/20220304111626_dd3bceaa08d1017415a555a1e55ede05.jpg
#   inflating: data/黄豆蒸排骨@GUANGWAI_20220614/20220304111626_dd3bceaa08d1017415a555a1e55ede05.txt
#   inflating: data/蒜香粉肠@ZHONGGUANGHE_20220901/2022072812085621_150&153&582&642_蛏子_61.txt
#   inflating: data/蒜香粉肠@ZHONGGUANGHE_20220901/2022072812085621_150&153&582&642_蛏子_61.jpg
#   inflating: data/菠菜肉片@shanda_20230104/20220309113344_TC14D16T40024_b85ef12f9f5911ecad0130d042ea3a21__400&61&635&273.txt
#   inflating: data/菠菜肉片@shanda_20230104/20220309113344_TC14D16T40024_b85ef12f9f5911ecad0130d042ea3a21__400&61&635&273.jpg
#   inflating: data/梅菜@ZHONGGUANGHE_20220901/20220707175043-2.jpg
#   inflating: data/梅菜@ZHONGGUANGHE_20220901/20220707175043-2.txt
#   inflating: data/皮蛋瘦肉粥@ZHONGGUANGHE_20220901/2022070908064120__724&662&1317&1197.jpg
#   inflating: data/皮蛋瘦肉粥@ZHONGGUANGHE_20220901/2022070908064120__724&662&1317&1197.txt
#   inflating: data/酱三样@SHANDA_20211201/20211019114857_TC14D16T40024_7cd52076308f11ecb6e730d042ea3a21__338&361&696&841.txt
#   inflating: data/酱三样@SHANDA_20211201/20211019114857_TC14D16T40024_7cd52076308f11ecb6e730d042ea3a21__338&361&696&841.jpg
#   inflating: data/花卷3@SHANDA_20211201/20211126115410_TC02211M40536_8321aecc4e6c11ec82f530d042ea3a21__195&113&444&325.txt
#   inflating: data/花卷3@SHANDA_20211201/20211126115410_TC02211M40536_8321aecc4e6c11ec82f530d042ea3a21__195&113&444&325.jpg
#   inflating: data/豆腐片白菜@20190717_GXSJT_SXDX/山西大学-托盘-中餐-20190116165442_33165$478_488_901_908.txt
#   inflating: data/豆腐片白菜@20190717_GXSJT_SXDX/山西大学-托盘-中餐-20190116165442_33165$478_488_901_908.jpg
#   inflating: data/133@JKDISH_20211230/25700.txt
#   inflating: data/133@JKDISH_20211230/25700.jpg
#   inflating: data/腐竹蒜苗肉丝2@njzw_20210829/20210506113322_8190820014243_00044bded76f__240&564&608&918.txt
#   inflating: data/腐竹蒜苗肉丝2@njzw_20210829/20210506113322_8190820014243_00044bded76f__240&564&608&918.jpg
#   inflating: data/黄瓜@20190717_GXSJT_ZCGJJG/诸城高级技工学校-托盘-中餐-20190116165424_20065$387_374_807_877.jpg
#   inflating: data/黄瓜@20190717_GXSJT_ZCGJJG/诸城高级技工学校-托盘-中餐-20190116165424_20065$387_374_807_877.txt
#   inflating: data/杂粮紫薯@njzw_20210829/20200501110103__897&323&1228&632.jpg
#   inflating: data/杂粮紫薯@njzw_20210829/20200501110103__897&323&1228&632.txt
#   inflating: data/92@JKDISH_20211230/12061.txt
#   inflating: data/92@JKDISH_20211230/12061.jpg
#   inflating: data/萝卜牛肚@ZHONGGUANGHE_20220901/20220705175106-4.txt
#   inflating: data/萝卜牛肚@ZHONGGUANGHE_20220901/20220705175106-4.jpg
#   inflating: data/回锅肉蒜苔花菜@HBSY_20210706_001/20210510181809_8190820014246_00044bdfac3f$1011_167_1353_505.txt
#   inflating: data/回锅肉蒜苔花菜@HBSY_20210706_001/20210510181809_8190820014246_00044bdfac3f$1011_167_1353_505.jpg
#   inflating: data/黄瓜片小咸菜@njzw_20210829/20210514073531_8190820012270_00044be03557__963&181&1199&290.txt
#   inflating: data/黄瓜片小咸菜@njzw_20210829/20210514073531_8190820012270_00044be03557__963&181&1199&290.jpg
#   inflating: data/黄瓜拌红烧肉@shanda_20230104/20220621120557_TC02211M40536_742bb27af11711ecb6b330d042ea3a21__130&50&380&328.jpg
#   inflating: data/黄瓜拌红烧肉@shanda_20230104/20220621120557_TC02211M40536_742bb27af11711ecb6b330d042ea3a21__130&50&380&328.txt
#   inflating: data/佛手瓜肉片@ZHONGGUANGHE_20220901/20220726172845-1.jpg
#   inflating: data/佛手瓜肉片@ZHONGGUANGHE_20220901/20220726172845-1.txt
#   inflating: data/萝卜干炒蛋@ZHONGGUANGHE_20220901/2022080511540120_123&245&605&721_萝卜干炒蛋_82.txt
#   inflating: data/萝卜干炒蛋@ZHONGGUANGHE_20220901/2022080511540120_123&245&605&721_萝卜干炒蛋_82.jpg
#   inflating: data/1_13_44__面包_42____0/北大菜品&20190520190150_8&480&300&801&867.jpg
#   inflating: data/1_13_44__面包_42____0/北大菜品&20190520190150_8&480&300&801&867.txt
#   inflating: data/3_34_41__肉_24_架豆角_25__0/高校-爱数&上海大学-托盘-晚餐-20190110145055_3323_9&1110&124&1499&540.jpg
#   inflating: data/3_34_41__肉_24_架豆角_25__0/高校-爱数&上海大学-托盘-晚餐-20190110145055_3323_9&1110&124&1499&540.txt
#   inflating: data/5_51_52__香干_21____0/高校-爱数&南理工紫金学院-托盘-晚餐-20181127152344_595_13&546&609&893&896.jpg
#   inflating: data/5_51_52__香干_21____0/高校-爱数&南理工紫金学院-托盘-晚餐-20181127152344_595_13&546&609&893&896.txt
#   inflating: data/圆饼2@20190717_GXSJT_HBKJDX/河北科技大学-托盘-早餐-20190116165358_20$1066_254_1562_721.txt
#   inflating: data/圆饼2@20190717_GXSJT_HBKJDX/河北科技大学-托盘-早餐-20190116165358_20$1066_254_1562_721.jpg
#   inflating: data/3_34_42__肉_31_萝卜_31__0-2/高校-爱数&南理工紫金学院-托盘-晚餐-20181127152344_620_8&575&83&904&449.txt
#   inflating: data/3_34_42__肉_31_萝卜_31__0-2/高校-爱数&南理工紫金学院-托盘-晚餐-20181127152344_620_8&575&83&904&449.jpg
#   inflating: data/肉沫豆腐@SHANDA_20211201/20211122113346_TC14D16T40024_ff12e9ff4b4411ec82f530d042ea3a21__500&110&715&330.jpg
#   inflating: data/肉沫豆腐@SHANDA_20211201/20211122113346_TC14D16T40024_ff12e9ff4b4411ec82f530d042ea3a21__500&110&715&330.txt
#   inflating: data/上校鸡块@HGD_20211221/20200103114216color8__1057&166&1665&833.jpg
#   inflating: data/上校鸡块@HGD_20211221/20200103114216color8__1057&166&1665&833.txt
#   inflating: data/4_41_41__茄子_31_土豆_31_青椒_25/北大菜品&地三鲜_20190319141034_66_7&710&423&1191&910.jpg
#   inflating: data/4_41_41__茄子_31_土豆_31_青椒_25/北大菜品&地三鲜_20190319141034_66_7&710&423&1191&910.txt
#   inflating: data/玉米粒@GUANGWAI_20220614/20220222115452_KM16D0B540147_20220222115452_30aa2d249393__499&638&889&1057.jpg
#   inflating: data/玉米粒@GUANGWAI_20220614/20220222115452_KM16D0B540147_20220222115452_30aa2d249393__499&638&889&1057.txt
#   inflating: data/蒸饺@HBSY_20210706_001/20210507064853_8190820014216_00044bdf17d1$451_231_817_536.jpg
#   inflating: data/蒸饺@HBSY_20210706_001/20210507064853_8190820014216_00044bdf17d1$451_231_817_536.txt
#   inflating: data/窝笋丝鸡蛋@njzw_20210829/20200506102054__499&263&891&683.jpg
#   inflating: data/窝笋丝鸡蛋@njzw_20210829/20200506102054__499&263&891&683.txt
#   inflating: data/小米粥@20190717_GXSJT_ZCGJJG/诸城高级技工学校-托盘-早餐-20190116165359_620$939_248_1303_613.jpg
#   inflating: data/小米粥@20190717_GXSJT_ZCGJJG/诸城高级技工学校-托盘-早餐-20190116165359_620$939_248_1303_613.txt
#   inflating: data/红烧猪脚@GUANGWAI_20220614/20220223115953_KM16D0B540160_20220223115953_0e20bdac945d__187&105&592&519.txt
#   inflating: data/红烧猪脚@GUANGWAI_20220614/20220223115953_KM16D0B540160_20220223115953_0e20bdac945d__187&105&592&519.jpg
#   inflating: data/黄花菜@njzw_20210829/20200608103008_8190820014265_00044bdf1b76__730&132&1138&493.jpg
#   inflating: data/黄花菜@njzw_20210829/20200608103008_8190820014265_00044bdf1b76__730&132&1138&493.txt
#   inflating: data/蒜苗鸡杂@njzw_20210829/20210528113614_8190820012270_00044be03557__361&223&740&582.txt
#   inflating: data/蒜苗鸡杂@njzw_20210829/20210528113614_8190820012270_00044be03557__361&223&740&582.jpg
#   inflating: data/肉丝面@HGD_20211221/20201127170915_8190820014235_00044bdf3fdd__526&275&996&768.txt
#   inflating: data/肉丝面@HGD_20211221/20201127170915_8190820014235_00044bdf3fdd__526&275&996&768.jpg
#   inflating: data/冬瓜鱼丸@shanda_20230104/20220323114402_TC45P1CR40369_7b1d3dccaa5b11ecb6b330d042ea3a21__551&121&800&358.jpg
#   inflating: data/冬瓜鱼丸@shanda_20230104/20220323114402_TC45P1CR40369_7b1d3dccaa5b11ecb6b330d042ea3a21__551&121&800&358.txt
#   inflating: data/香菇粉丝汤@HGD_20211221/20210326121628_8190820012282_00044bdebaf5$314_287_699_685.jpg
#   inflating: data/香菇粉丝汤@HGD_20211221/20210326121628_8190820012282_00044bdebaf5$314_287_699_685.txt
#   inflating: data/花卷@20190717_GXSJT_LYDX-8/临沂大学-托盘-中餐-20190116165406_6151$808_144_1032_458.txt
#   inflating: data/花卷@20190717_GXSJT_LYDX-8/临沂大学-托盘-中餐-20190116165406_6151$808_144_1032_458.jpg
#   inflating: data/青枣@GUANGWAI_20220614/20220418113347_KM16D0B540147_20220418113347_5b561582bec8__1216&648&1421&868.txt
#   inflating: data/青枣@GUANGWAI_20220614/20220418113347_KM16D0B540147_20220418113347_5b561582bec8__1216&648&1421&868.jpg
#   inflating: data/菠菜A@20190717_GXSJT_SXDX-3/山西大学-托盘-中餐-20190116165447_35557$478_492_877_940_SAMPLE.jpg
#   inflating: data/菠菜A@20190717_GXSJT_SXDX-3/山西大学-托盘-中餐-20190116165447_35557$478_492_877_940_SAMPLE.txt
#   inflating: data/猪肝@HGD_20211221/P90_20191114162338__427&272&573&453.jpg
#   inflating: data/猪肝@HGD_20211221/P90_20191114162338__427&272&573&453.txt
#   inflating: data/美味泡菜@HGD_20220901/202208161728188__677&741&1157&1102.jpg
#   inflating: data/美味泡菜@HGD_20220901/202208161728188__677&741&1157&1102.txt
#   inflating: data/1_13_12_金黄_饼_41_芝麻___0/南京政务&20191126080051_6&552&120&726&266.txt
#   inflating: data/1_13_12_金黄_饼_41_芝麻___0/南京政务&20191126080051_6&552&120&726&266.jpg
#   inflating: data/杏鲍菇炒肉@GUANGWAI_20220614/20220323175034_KM16D0B540160_20220323175034_af4bc63aaa8e__1020&235&1450&666.jpg
#   inflating: data/杏鲍菇炒肉@GUANGWAI_20220614/20220323175034_KM16D0B540160_20220323175034_af4bc63aaa8e__1020&235&1450&666.txt
#   inflating: data/芹菜粉@HGD_20211221/20200103172623color11__1048&720&1427&1116.jpg
#   inflating: data/芹菜粉@HGD_20211221/20200103172623color11__1048&720&1427&1116.txt
#   inflating: data/糖醋瓦块鱼土豆泥拼盘@HGD_20211221/20201204173313_8190820014252_00044bdf1b5e__434&156&889&551.txt
#   inflating: data/糖醋瓦块鱼土豆泥拼盘@HGD_20211221/20201204173313_8190820014252_00044bdf1b5e__434&156&889&551.jpg
#   inflating: data/紫甘蓝@20190717-XML-20190620-BDNY/高校-爱数&山东聊城大学-托盘-中餐-20181201164241_132_9&1143&326&1545&748.jpg
#   inflating: data/紫甘蓝@20190717-XML-20190620-BDNY/高校-爱数&山东聊城大学-托盘-中餐-20181201164241_132_9&1143&326&1545&748.txt
#   inflating: data/菌菇滑蛋@SHANDA_20211201/20220705120023_TC45P1CR40512_fe7fa3befc1611ec9b1c30d042ea3a21__449&121&724&359.txt
#   inflating: data/菌菇滑蛋@SHANDA_20211201/20220705120023_TC45P1CR40512_fe7fa3befc1611ec9b1c30d042ea3a21__449&121&724&359.jpg
#   inflating: data/煎海杂鱼@ZHONGGUANGHE_20220901/2022072211535220_821&149&1594&770_5元菜_58.jpg
#   inflating: data/煎海杂鱼@ZHONGGUANGHE_20220901/2022072211535220_821&149&1594&770_5元菜_58.txt
#   inflating: data/木耳小白菜@HGD_20211221/20200106170135__1093&615&1676&1216.jpg
#   inflating: data/木耳小白菜@HGD_20211221/20200106170135__1093&615&1676&1216.txt
#   inflating: data/香芹豆腐丝@GUANGWAI_20220614/20220331114116_KM16D0B540147_20220331114116_6ba66a40b0a4__844&702&1296&1143.jpg
#   inflating: data/香芹豆腐丝@GUANGWAI_20220614/20220331114116_KM16D0B540147_20220331114116_6ba66a40b0a4__844&702&1296&1143.txt
#   inflating: data/3_33_33__鹅_31_莴笋_31_胡萝卜_31__0/南京政务&20191122172556_6&452&152&656&331.txt
#   inflating: data/3_33_33__鹅_31_莴笋_31_胡萝卜_31__0/南京政务&20191122172556_6&452&152&656&331.jpg
#   inflating: data/肥肠@njzw_20210829/北大菜品&爆炒肥肠_20190313161302_148_7&729&667&1279&1197.jpg
#   inflating: data/肥肠@njzw_20210829/北大菜品&爆炒肥肠_20190313161302_148_7&729&667&1279&1197.txt
#   inflating: data/海鲜菇炒塔菜2@HGD_20220901/202208161110558_352&405&1174&804_海鲜菇炒塔菜_99.jpg
#   inflating: data/海鲜菇炒塔菜2@HGD_20220901/202208161110558_352&405&1174&804_海鲜菇炒塔菜_99.txt
#   inflating: data/4_41_21__杏鲍菇_11_木耳_11__0/高校-爱数&山东聊城大学-托盘-晚餐-20181201164446_406_10&300&152&686&536.txt
#   inflating: data/4_41_21__杏鲍菇_11_木耳_11__0/高校-爱数&山东聊城大学-托盘-晚餐-20181201164446_406_10&300&152&686&536.jpg
#   inflating: data/腐乳橄榄菜@ZHONGGUANGHE_20220901/2022070706570620_939&34&1209&310_汤大晚餐_70.jpg
#   inflating: data/腐乳橄榄菜@ZHONGGUANGHE_20220901/2022070706570620_939&34&1209&310_汤大晚餐_70.txt
#   inflating: data/煎蛋@njzw_20210829/20210521083044_8190820012282_00044bdebaf5__946&317&1163&550.jpg
#   inflating: data/煎蛋@njzw_20210829/20210521083044_8190820012282_00044bdebaf5__946&317&1163&550.txt
#   inflating: data/木耳山药青豆@njzw_20210829/20200508184133__510&266&919&660.jpg
#   inflating: data/木耳山药青豆@njzw_20210829/20200508184133__510&266&919&660.txt
#   inflating: data/孜然鱼豆腐@HGD_20211221/20201130114321_8190820014199_00044bdf143f__343&472&733&866.txt
#   inflating: data/孜然鱼豆腐@HGD_20211221/20201130114321_8190820014199_00044bdf143f__343&472&733&866.jpg

# %%
# %%capture
import os
if "COLAB_" not in "".join(os.environ.keys()):
    # !pip install unsloth
else:
    # Do this only in Colab notebooks! Otherwise use pip install unsloth
    # !pip install --no-deps bitsandbytes accelerate xformers==0.0.29.post3 peft trl==0.15.2 triton cut_cross_entropy unsloth_zoo
    # !pip install sentencepiece protobuf "datasets>=3.4.1" huggingface_hub hf_transfer
    # !pip install --no-deps unsloth

# %% [markdown]
# ### Unsloth

# %%
from unsloth import FastVisionModel # FastLanguageModel for LLMs
import torch

# 4bit pre quantized models we support for 4x faster downloading + no OOMs.
fourbit_models = [
    "unsloth/Llama-3.2-11B-Vision-Instruct-bnb-4bit", # Llama 3.2 vision support
    "unsloth/Llama-3.2-11B-Vision-bnb-4bit",
    "unsloth/Llama-3.2-90B-Vision-Instruct-bnb-4bit", # Can fit in a 80GB card!
    "unsloth/Llama-3.2-90B-Vision-bnb-4bit",

    "unsloth/Pixtral-12B-2409-bnb-4bit",              # Pixtral fits in 16GB!
    "unsloth/Pixtral-12B-Base-2409-bnb-4bit",         # Pixtral base model

    "unsloth/Qwen2-VL-2B-Instruct-bnb-4bit",          # Qwen2 VL support
    "unsloth/Qwen2-VL-7B-Instruct-bnb-4bit",
    "unsloth/Qwen2-VL-72B-Instruct-bnb-4bit",

    "unsloth/llava-v1.6-mistral-7b-hf-bnb-4bit",      # Any Llava variant works!
    "unsloth/llava-1.5-7b-hf-bnb-4bit",
] # More models at https://huggingface.co/unsloth

model, tokenizer = FastVisionModel.from_pretrained(
    "unsloth/Qwen2-VL-7B-Instruct",
    load_in_4bit = True, # Use 4bit to reduce memory use. False for 16bit LoRA.
    use_gradient_checkpointing = "unsloth", # True or "unsloth" for long context
)
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# /content/unsloth_compiled_cache/unsloth_compiled_module_qwen2.py:526: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if () is not None or () != ():
# ==((====))==  Unsloth 2025.5.1: Fast Qwen2_Vl patching. Transformers: 4.51.3.
#    \\   /|    Tesla T4. Num GPUs = 1. Max memory: 14.741 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.6.0+cu124. CUDA: 7.5. CUDA Toolkit: 12.4. Triton: 3.2.0
# \        /    Bfloat16 = FALSE. FA [Xformers = 0.0.29.post3. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# model.safetensors:   0%|          | 0.00/6.85G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/238 [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/572 [00:00<?, ?B/s]
# Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.52, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.
# tokenizer_config.json:   0%|          | 0.00/4.33k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/2.78M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/1.67M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/11.4M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/392 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/614 [00:00<?, ?B/s]
# chat_template.json:   0%|          | 0.00/1.05k [00:00<?, ?B/s]

# %% [markdown]
# We now add LoRA adapters for parameter efficient finetuning - this allows us to only efficiently train 1% of all parameters.
#
# **[NEW]** We also support finetuning ONLY the vision part of the model, or ONLY the language part. Or you can select both! You can also select to finetune the attention or the MLP layers!

# %%
model = FastVisionModel.get_peft_model(
    model,
    finetune_vision_layers     = True, # False if not finetuning vision layers
    finetune_language_layers   = True, # False if not finetuning language layers
    finetune_attention_modules = True, # False if not finetuning attention layers
    finetune_mlp_modules       = True, # False if not finetuning MLP layers

    r = 16,           # The larger, the higher the accuracy, but might overfit
    lora_alpha = 16,  # Recommended alpha == r at least
    lora_dropout = 0,
    bias = "none",
    random_state = 3407,
    use_rslora = False,  # We support rank stabilized LoRA
    loftq_config = None, # And LoftQ
    # target_modules = "all-linear", # Optional now! Can specify a list if needed
)
# Out:
# Unsloth: Making `model.base_model.model.visual` require gradients

# %% [markdown]
# <a name="Data"></a>
# ### Data Prep
# We'll be using a sampled dataset of handwritten maths formulas. The goal is to convert these images into a computer readable form - ie in LaTeX form, so we can render it. This can be very useful for complex formulas.
#
# You can access the dataset [here](https://huggingface.co/datasets/unsloth/LaTeX_OCR). The full dataset is [here](https://huggingface.co/datasets/linxy/LaTeX_OCR).

# %%
from datasets import load_dataset, Features, Value, Image
dataset = load_dataset(
    "json",
    data_files="data.jsonl",
    features=Features({
        "image": Image(),          # 会自动加载图片为 PIL.Image
        "target": Value("string")  # 文本目标是 JSON 字符串
    })
)
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]

# %%
# !ls
# Out:
# data	  generate_jsonl.py  sample_data
# data.zip  __MACOSX	     unsloth_compiled_cache

# %% [markdown]
# Let's take an overview look at the dataset. We shall see what the 3rd image is, and what caption it had.

# %%
dataset = dataset["train"]

# %%
dataset[2]["image"]
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=530x528>

# %%
dataset[2]["target"]
# Out:
# '{"name": "麻辣香锅", "cuisine": "川菜", "cooking_method": "炒", "ingredients": "青椒,火腿肠,藕,木耳,土豆"}'

# %% [markdown]
# We can also render the LaTeX in the browser directly!

# %%
from IPython.display import display, Math, Latex

latex = dataset[2]["text"]
display(Math(latex))
# Out:
# $\displaystyle H ^ { \prime } = \beta N \int d \lambda \biggl \{ \frac { 1 } { 2 \beta ^ { 2 } N ^ { 2 } } \partial _ { \lambda } \zeta ^ { \dagger } \partial _ { \lambda } \zeta + V ( \lambda ) \zeta ^ { \dagger } \zeta \biggr \} \ .$

# %% [markdown]
# To format the dataset, all vision finetuning tasks should be formatted as follows:
#
# ```python
# [
# { "role": "user",
#   "content": [{"type": "text",  "text": Q}, {"type": "image", "image": image} ]
# },
# { "role": "assistant",
#   "content": [{"type": "text",  "text": A} ]
# },
# ]
# ```

# %%
def convert_to_conversation(sample):
    system_prompt = (
      "你是一个强大的菜品食材识别智能体，能够精准识别各类菜品与各类水果，"
      "并清晰指出该菜品所使用的对应食材、烹饪方式、菜系等信息。"
      "输出格式为严格 JSON，字段包括 name、cuisine、cooking_method、ingredients，"
      "若是水果，仅输出名称，其余为空。不得添加解释文字。"
    )
    conversation = [
        {
            "role": "system",
            "content": system_prompt
        },
        { "role": "user",
          "content" : [
            {"type" : "text",  "text"  : "请分析以下图片的菜品语义信息，并输出 JSON 格式结构"},
            {"type" : "image", "image" : sample["image"]} ]
        },
        { "role" : "assistant",
          "content" : [
            {"type" : "text",  "text"  : sample["target"]} ]
        },
    ]
    return { "messages" : conversation }

converted_dataset = [convert_to_conversation(sample) for sample in dataset]

# %% [markdown]
# Let's convert the dataset into the "correct" format for finetuning:

# %%
converted_dataset = [convert_to_conversation(sample) for sample in dataset]

# %% [markdown]
# We look at how the conversations are structured for the first example:

# %%
converted_dataset[0]
# Out:
# {'messages': [{'role': 'system',
#    'content': '你是一个强大的菜品食材识别智能体，能够精准识别各类菜品与各类水果，并清晰指出该菜品所使用的对应食材、烹饪方式、菜系等信息。输出格式为严格 JSON，字段包括 name、cuisine、cooking_method、ingredients，若是水果，仅输出名称，其余为空。不得添加解释文字。'},
#   {'role': 'user',
#    'content': [{'type': 'text', 'text': '请分析以下图片的菜品语义信息，并输出 JSON 格式结构'},
#     {'type': 'image',
#      'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=237x235>}]},
#   {'role': 'assistant',
#    'content': [{'type': 'text',
#      'text': '{"name": "豆沙饼", "cuisine": "", "cooking_method": "烤", "ingredients": "豆沙"}'}]}]}

# %% [markdown]
# Let's first see before we do any finetuning what the model outputs for the first example!

# %%
FastVisionModel.for_inference(model) # Enable for inference!

image = dataset[2]["image"]
instruction = "Write the LaTeX representation for this image."

messages = [
    {"role": "user", "content": [
        {"type": "image"},
        {"type": "text", "text": instruction}
    ]}
]
input_text = tokenizer.apply_chat_template(messages, add_generation_prompt = True)
inputs = tokenizer(
    image,
    input_text,
    add_special_tokens = False,
    return_tensors = "pt",
).to("cuda")

from transformers import TextStreamer
text_streamer = TextStreamer(tokenizer, skip_prompt = True)
_ = model.generate(**inputs, streamer = text_streamer, max_new_tokens = 128,
                   use_cache = True, temperature = 1.5, min_p = 0.1)
# Out:
# $$\mathrm { ~ n a ~ }$$<|im_end|>

# %% [markdown]
# <a name="Train"></a>
# ### Train the model
# Now let's use Huggingface TRL's `SFTTrainer`! More docs here: [TRL SFT docs](https://huggingface.co/docs/trl/sft_trainer). We do 60 steps to speed things up, but you can set `num_train_epochs=1` for a full run, and turn off `max_steps=None`. We also support TRL's `DPOTrainer`!
#
# We use our new `UnslothVisionDataCollator` which will help in our vision finetuning setup.

# %%
from unsloth import is_bf16_supported
from unsloth.trainer import UnslothVisionDataCollator
from trl import SFTTrainer, SFTConfig

FastVisionModel.for_training(model) # Enable for training!

trainer = SFTTrainer(
    model = model,
    tokenizer = tokenizer,
    data_collator = UnslothVisionDataCollator(model, tokenizer), # Must use!
    train_dataset = converted_dataset,
    args = SFTConfig(
        per_device_train_batch_size = 2,
        gradient_accumulation_steps = 4,
        warmup_steps = 5,
        # max_steps = 30,
        num_train_epochs = 10, # Set this instead of max_steps for full training runs
        learning_rate = 2e-4,
        fp16 = not is_bf16_supported(),
        bf16 = is_bf16_supported(),
        logging_steps = 1,
        optim = "adamw_8bit",
        weight_decay = 0.01,
        lr_scheduler_type = "linear",
        seed = 3407,
        output_dir = "outputs",
        report_to = "none",     # For Weights and Biases

        # You MUST put the below items for vision finetuning:
        remove_unused_columns = False,
        dataset_text_field = "",
        dataset_kwargs = {"skip_prepare_dataset": True},
        dataset_num_proc = 4,
        max_seq_length = 2048,
    ),
)
# Out:
# Unsloth: Model does not have a default image size - using 512

# %%
# @title Show current memory stats
gpu_stats = torch.cuda.get_device_properties(0)
start_gpu_memory = round(torch.cuda.max_memory_reserved() / 1024 / 1024 / 1024, 3)
max_memory = round(gpu_stats.total_memory / 1024 / 1024 / 1024, 3)
print(f"GPU = {gpu_stats.name}. Max memory = {max_memory} GB.")
print(f"{start_gpu_memory} GB of memory reserved.")
# Out:
# GPU = Tesla T4. Max memory = 14.748 GB.
# 6.131 GB of memory reserved.

# %%
trainer_stats = trainer.train()
# Out:
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs used = 1
#    \\   /|    Num examples = 740 | Num Epochs = 10 | Total steps = 920
# O^O/ \_/ \    Batch size per device = 2 | Gradient accumulation steps = 4
# \        /    Data Parallel GPUs = 1 | Total batch size (2 x 4 x 1) = 8
#  "-____-"     Trainable parameters = 50,855,936/7,000,000,000 (0.73% trained)
# `use_cache=True` is incompatible with gradient checkpointing. Setting `use_cache=False`...
# Unsloth: Will smartly offload gradients to save VRAM!
#     <div>
#
#       <progress value='13' max='920' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 13/920 02:28 < 3:23:25, 0.07 it/s, Epoch 0.13/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>3.108500</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>3.082100</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>3.029800</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>2.848000</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>2.895300</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>2.616800</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>2.305600</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>2.279300</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>1.882700</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>1.556500</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>1.114300</td>
#     </tr>
#   </tbody>
# </table><p>

# %%
# @title Show final memory and time stats
used_memory = round(torch.cuda.max_memory_reserved() / 1024 / 1024 / 1024, 3)
used_memory_for_lora = round(used_memory - start_gpu_memory, 3)
used_percentage = round(used_memory / max_memory * 100, 3)
lora_percentage = round(used_memory_for_lora / max_memory * 100, 3)
print(f"{trainer_stats.metrics['train_runtime']} seconds used for training.")
print(
    f"{round(trainer_stats.metrics['train_runtime']/60, 2)} minutes used for training."
)
print(f"Peak reserved memory = {used_memory} GB.")
print(f"Peak reserved memory for training = {used_memory_for_lora} GB.")
print(f"Peak reserved memory % of max memory = {used_percentage} %.")
print(f"Peak reserved memory for training % of max memory = {lora_percentage} %.")
# Out:
# 314.6248 seconds used for training.
# 5.24 minutes used for training.
# Peak reserved memory = 7.508 GB.
# Peak reserved memory for training = 1.377 GB.
# Peak reserved memory % of max memory = 50.909 %.
# Peak reserved memory for training % of max memory = 9.337 %.

# %% [markdown]
# <a name="Inference"></a>
# ### Inference
# Let's run the model! You can change the instruction and input - leave the output blank!
#
# We use `min_p = 0.1` and `temperature = 1.5`. Read this [Tweet](https://x.com/menhguin/status/1826132708508213629) for more information on why.

# %%
FastVisionModel.for_inference(model) # Enable for inference!

image = dataset[2]["image"]
instruction = "Write the LaTeX representation for this image."

messages = [
    {"role": "user", "content": [
        {"type": "image"},
        {"type": "text", "text": instruction}
    ]}
]
input_text = tokenizer.apply_chat_template(messages, add_generation_prompt = True)
inputs = tokenizer(
    image,
    input_text,
    add_special_tokens = False,
    return_tensors = "pt",
).to("cuda")

from transformers import TextStreamer
text_streamer = TextStreamer(tokenizer, skip_prompt = True)
_ = model.generate(**inputs, streamer = text_streamer, max_new_tokens = 128,
                   use_cache = True, temperature = 1.5, min_p = 0.1)
# Out:
# \left( \frac { \partial } { \partial x } \right) ^ { 2 } \phi = \frac { 1 } { 2 } \left( \frac { \partial } { \partial x } \right) ^ { 2 } \phi _ { 0 } + \frac { 1 } { 2 } \left( \frac { \partial } { \partial x } \right) ^ { 2 } \phi _ { 1 } + \frac { 1 } { 2 } \left( \frac { \partial } { \partial x

# %% [markdown]
# <a name="Save"></a>
# ### Saving, loading finetuned models
# To save the final model as LoRA adapters, either use Huggingface's `push_to_hub` for an online save or `save_pretrained` for a local save.
#
# **[NOTE]** This ONLY saves the LoRA adapters, and not the full model. To save to 16bit or GGUF, scroll down!

# %%
model.save_pretrained("lora_model")  # Local saving
tokenizer.save_pretrained("lora_model")
# model.push_to_hub("your_name/lora_model", token = "...") # Online saving
# tokenizer.push_to_hub("your_name/lora_model", token = "...") # Online saving
# Out:
# []

# %% [markdown]
# Now if you want to load the LoRA adapters we just saved for inference, set `False` to `True`:

# %%
if False:
    from unsloth import FastVisionModel
    model, tokenizer = FastVisionModel.from_pretrained(
        model_name = "lora_model", # YOUR MODEL YOU USED FOR TRAINING
        load_in_4bit = True, # Set to False for 16bit LoRA
    )
    FastVisionModel.for_inference(model) # Enable for inference!

image = dataset[0]["image"]
instruction = "Write the LaTeX representation for this image."

messages = [
    {"role": "user", "content": [
        {"type": "image"},
        {"type": "text", "text": instruction}
    ]}
]
input_text = tokenizer.apply_chat_template(messages, add_generation_prompt = True)
inputs = tokenizer(
    image,
    input_text,
    add_special_tokens = False,
    return_tensors = "pt",
).to("cuda")

from transformers import TextStreamer
text_streamer = TextStreamer(tokenizer, skip_prompt = True)
_ = model.generate(**inputs, streamer = text_streamer, max_new_tokens = 128,
                   use_cache = True, temperature = 1.5, min_p = 0.1)
# Out:
# \left( \frac { \partial _ { \mu } \phi } { \partial _ { \mu } \phi ^ { * } } \right) ^ { 2 } = \frac { 1 } { 2 } \left( \frac { \partial _ { \mu } \phi } { \partial _ { \mu } \phi ^ { * } } \right) ^ { 2 } \left( \frac { \partial _ { \mu } \phi ^ { * } } { \partial _ { \mu } \phi } \right) ^ { 2 }

# %% [markdown]
# ### Saving to float16 for VLLM
#
# We also support saving to `float16` directly. Select `merged_16bit` for float16. Use `push_to_hub_merged` to upload to your Hugging Face account! You can go to https://huggingface.co/settings/tokens for your personal tokens.

# %%
# Select ONLY 1 to save! (Both not needed!)

# Save locally to 16bit
if False: model.save_pretrained_merged("unsloth_finetune", tokenizer,)

# To export and save to your Hugging Face account
if False: model.push_to_hub_merged("YOUR_USERNAME/unsloth_finetune", tokenizer, token = "PUT_HERE")

# %% [markdown]
# And we're done! If you have any questions on Unsloth, we have a [Discord](https://discord.gg/u54VK8m8tk) channel! If you find any bugs or want to keep updated with the latest LLM stuff, or need help, join projects etc, feel free to join our Discord!
#
# Some other links:
# 1. Train your own reasoning model - Llama GRPO notebook [Free Colab](https://colab.research.google.com/github/unslothai/notebooks/blob/main/nb/Llama3.1_(8B)-GRPO.ipynb)
# 2. Saving finetunes to Ollama. [Free notebook](https://colab.research.google.com/github/unslothai/notebooks/blob/main/nb/Llama3_(8B)-Ollama.ipynb)
# 3. Llama 3.2 Vision finetuning - Radiography use case. [Free Colab](https://colab.research.google.com/github/unslothai/notebooks/blob/main/nb/Llama3.2_(11B)-Vision.ipynb)
# 6. See notebooks for DPO, ORPO, Continued pretraining, conversational finetuning and more on our [documentation](https://docs.unsloth.ai/get-started/unsloth-notebooks)!
#
# <div class="align-center">
#   <a href="https://unsloth.ai"><img src="https://github.com/unslothai/unsloth/raw/main/images/unsloth%20new%20logo.png" width="115"></a>
#   <a href="https://discord.gg/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/Discord.png" width="145"></a>
#   <a href="https://docs.unsloth.ai/"><img src="https://github.com/unslothai/unsloth/blob/main/images/documentation%20green%20button.png?raw=true" width="125"></a>
#
#   Join Discord if you need help + ⭐️ <i>Star us on <a href="https://github.com/unslothai/unsloth">Github</a> </i> ⭐️
# </div>
